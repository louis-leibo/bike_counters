# %%
import pandas as pd
import numpy as np

from skrub import TableVectorizer
import xgboost as xgb
from sklearn.pipeline import Pipeline

import holidays

from datetime import datetime

from sklearn.model_selection import RandomizedSearchCV

from sklearn.preprocessing import StandardScaler, LabelEncoder

import datetime

from catboost import CatBoostRegressor

from sklearn.model_selection import train_test_split

# %%
# Import the files
df_train = pd.read_parquet("/Users/louisleibovici/Documents/VS_Code/Bike_counters DSB Project/bike_counters/data/train.parquet")
df_test = pd.read_parquet("/Users/louisleibovici/Documents/VS_Code/Bike_counters DSB Project/bike_counters/data/final_test.parquet")

# %%
# Add jour ferie data
jour_feries = (
    pd.read_csv(
        "/Users/louisleibovici/Documents/VS_Code/Bike_counters DSB Project/bike_counters/external_data/jours_feries_metropole.csv",
        date_format="%Y%m%d%H"  # Ensure date format is handled correctly
    )
    .drop(columns=["annee", "zone"])  # Drop unnecessary columns
)

# Convert 'date' column to datetime
jour_feries['date'] = pd.to_datetime(jour_feries['date'])

# Filter rows based on the date range of df_train and df_test
jour_feries = jour_feries[
    (jour_feries["date"] >= df_train["date"].min() - datetime.timedelta(hours=1))
    & (jour_feries["date"] <= df_test["date"].max() + datetime.timedelta(hours=1))
]

# %%
# Add mouvements sociaux data :
mouvements_sociaux = (
    pd.read_csv(
        "/Users/louisleibovici/Documents/VS_Code/Bike_counters DSB Project/bike_counters/external_data/mouvements-sociaux-depuis-2002.csv",
        date_format="%Y%m%d%H",
        sep=";"
    )
    .drop(columns=['date_de_fin', 'Organisations syndicales', 'Métiers ciblés par le préavis',
                   'Population devant travailler ciblee par le préavis', 'Nombre de grévistes du préavis'])  # Drop unnecessary columns
)

mouvements_sociaux['Date'] = pd.to_datetime(mouvements_sociaux['Date'])

mouvements_sociaux = mouvements_sociaux[
    (mouvements_sociaux["Date"] >= df_train["date"].min() - datetime.timedelta(hours=1))
    & (mouvements_sociaux["Date"] <= df_test["date"].max() + datetime.timedelta(hours=1))
]

mouvements_sociaux = mouvements_sociaux[mouvements_sociaux['Date'] != pd.Timestamp('2021-03-08')]

# %%
# Extract the date feature on different time scales :

fr_holidays = holidays.France()

def _encode_dates(X):
    X = X.copy()  # modify a copy of X
    # Encode the date information from the DateOfDeparture columns
    X["year"] = X["date"].dt.year
    X["month"] = X["date"].dt.month
    X["day"] = X["date"].dt.day
    X["weekday"] = X["date"].dt.weekday
    X["hour"] = X["date"].dt.hour

    # creation of a binary varible depicting if day in weekend
    X["is_weekend"] = np.where(X["weekday"] + 1 > 5, 1, 0)

    # Add a feature to indicate if the day is a holiday in France
    X["is_holiday"] = X["date"].apply(lambda d: 1 if d in fr_holidays else 0)

    # and if it is a jour ferie in France :
    X["is_jour_ferie"] = X["date"].dt.date.isin(jour_feries['date']).astype(int)

    # and it is a jour of "mouvement social" in France :
    X["is_jour_mouvement_social"] = X["date"].dt.date.isin(mouvements_sociaux['Date']).astype(int)

    # Add morning rush and evening rush features
    # X["is_working_day"] = np.where((X["weekday"] + 1 <= 5), 1, 0)
    # X["morning_rush"] = (X["hour"].between(7, 9)) & X["is_working_day"]
    # X["evening_rush"] = (X["hour"].between(17, 19)) & X["is_working_day"]

    # Add the season feature
    # def season_date(date):
      #  if (date > datetime.datetime(2020, 9, 21)) & (date < datetime.datetime(2020, 12, 21)):
       #     return 1
       # if (date > datetime.datetime(2020, 12, 20)) & (date < datetime.datetime(2021, 3, 20)):
       #     return 2
       # if (date > datetime.datetime(2021, 3, 19)) & (date < datetime.datetime(2021, 6, 21)):
       #     return 3
       # if ((date > datetime.datetime(2021, 6, 20)) & (date < datetime.datetime(2021, 9, 22))) | \
       #    ((date > datetime.datetime(2020, 6, 19)) & (date < datetime.datetime(2020, 9, 22))):
       #     return 4
       #  return 0  # fallback if none matches

    # X["season"] = X["date"].apply(season_date)

    return X

df_train = _encode_dates(df_train)
df_test = _encode_dates(df_test)

# %%
import geopandas as gpd
from shapely.geometry import Point

# To add an "arrondissement" feature based on latitute ande longitude
def arrondissement(X, shapefile_path="/Users/louisleibovici/Documents/VS_Code/Bike_counters DSB Project/bike_counters/external_data/arrondissements.shp"):

    arrondissements = gpd.read_file(shapefile_path)

    # Create a GeoDataFrame for the input dataset
    X = X.copy()  # Work on a copy of the dataset
    X["geometry"] = X.apply(lambda row: Point(row["longitude"], row["latitude"]), axis=1)
    gdf = gpd.GeoDataFrame(X, geometry="geometry", crs=arrondissements.crs)

    # Perform a spatial join to match points to arrondissements
    merged = gpd.sjoin(gdf, arrondissements, how="left", predicate="within")

    # Extract the arrondissement code (e.g., "c_ar") and fill missing values with 21
    X["district"] = merged["c_ar"].fillna(21).astype(int)

    # Drop the geometry column (optional, if not needed further)
    X = X.drop(columns=["geometry"])

    return X

df_train = arrondissement(df_train)
df_test = arrondissement(df_test)

# %%
'''
# To add covid features : one binary feature for lockdown and one binary feature for curfew periods
def covid_features(data):
    # Lockdown periods
    lockdown_periods = [
        ("2020-10-30", "2020-12-15"),
        ("2021-04-03", "2021-05-03"),
    ]

    # Binary column for lockdown
    data["is_lockdown"] = 0
    for start_date, end_date in lockdown_periods:
        data.loc[
            (data["date"] >= start_date) & (data["date"] < end_date),
            "is_lockdown"
        ] = 1

    # Curfew periods with specific time restrictions
    curfew_periods = [
        ("2020-10-17", "2020-10-30", 21, 6),  # Curfew from 9 PM to 6 AM
        ("2020-12-16", "2021-01-15", 20, 6),  # Curfew from 8 PM to 6 AM
        ("2021-01-15", "2021-03-20", 19, 6),  # Curfew from 7 PM to 6 AM
        ("2021-03-20", "2021-04-03", 18, 6),  # Curfew from 6 PM to 6 AM
        ("2021-05-03", "2021-06-09", 19, 6),  # Curfew from 7 PM to 6 AM
        ("2021-06-09", "2021-06-20", 23, 6),  # Curfew from 11 PM to 6 AM
    ]

    # Binary column for curfew
    data["is_curfew"] = 0
    for start_date, end_date, start_hour, end_hour in curfew_periods:
        data.loc[
            (data["date"] >= start_date) & (data["date"] < end_date)
            & ((data["hour"] >= start_hour) | (data["hour"] < end_hour)),
            "is_curfew"
        ] = 1

    return data

# Apply the function to your datasets
df_train = covid_features(df_train)
df_test = covid_features(df_test)
'''

# remove the date column
df_train = df_train.drop(columns=['date'])
df_test = df_test.drop(columns=['date'])

# %%
# Preprocessing :

# Extract features from counter_installation_date
for df in [df_train, df_test]:
    df["installation_year"] = df["counter_installation_date"].dt.year
    df["installation_month"] = df["counter_installation_date"].dt.month

df_train = df_train.drop(columns=["counter_installation_date"])
df_test = df_test.drop(columns=["counter_installation_date"])

# Label encode high-cardinality categorical features
label_encoders = {}
for col in ["counter_id", "site_id", "counter_name", "site_name", "counter_technical_id", "coordinates"]:
    le = LabelEncoder()
    df_train[col] = le.fit_transform(df_train[col])
    df_test[col] = le.fit_transform(df_test[col])
    label_encoders[col] = le

# %%
X_train = df_train.drop(columns=["bike_count", "log_bike_count"])
y_train = df_train["log_bike_count"]

X_test = df_test.copy()

# %%
# Step 1: Split data into train and validation sets
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42
)

# and sample a subset for hyperparameter tuning :
subset_size = int(0.4 * len(X_train_split))
subset_indices = np.random.choice(X_train_split.index, subset_size, replace=False)

X_subset = X_train_split.loc[subset_indices]
y_subset = y_train_split.loc[subset_indices]

# %%
# Step 2: Define parameter grid for RandomizedSearchCV
param_grid = {
    'iterations': [500, 1000, 2000],
    'learning_rate': [0.01, 0.05, 0.1],
    'depth': [6, 8, 10],
    'l2_leaf_reg': [1, 3, 5, 10],
    'bagging_temperature': [0.8, 1],
    'rsm': [0.8, 1.0]
}

# %%
# Step 3: Initialize CatBoost model
catboost_model = CatBoostRegressor(
    loss_function='RMSE',
    random_seed=42,
    verbose=100
)

# %%
# Step 4: Use RandomizedSearchCV to find the best parameters
random_search = RandomizedSearchCV(
    estimator=catboost_model,
    param_distributions=param_grid,
    scoring='neg_mean_squared_error',
    n_iter=50,
    cv=5,
    random_state=42,
    verbose=2,
    n_jobs=-1
)

# Perform the search
random_search.fit(X_subset, y_subset)

# Print best parameters and score
print("Best Parameters:", random_search.best_params_)
print("Best Score:", -random_search.best_score_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# 0:	learn: 1.5489309	total: 94.5ms	remaining: 3m 8s
# 0:	learn: 1.6063998	total: 98.5ms	remaining: 49.2s
# 0:	learn: 1.5478054	total: 131ms	remaining: 4m 22s
# 0:	learn: 1.5481287	total: 139ms	remaining: 4m 37s
# 0:	learn: 1.5503147	total: 96.2ms	remaining: 3m 12s
# 0:	learn: 1.6073151	total: 86.5ms	remaining: 43.2s
# 0:	learn: 1.6081019	total: 77.1ms	remaining: 38.5s
# 0:	learn: 1.5497505	total: 107ms	remaining: 3m 34s
# 100:	learn: 0.6539090	total: 2.62s	remaining: 10.3s
# 100:	learn: 0.6512441	total: 2.49s	remaining: 9.86s
# 100:	learn: 0.6513960	total: 2.76s	remaining: 10.9s
# 100:	learn: 0.5177510	total: 3.81s	remaining: 1m 11s
# 100:	learn: 0.5150731	total: 3.92s	remaining: 1m 13s
# 100:	learn: 0.5150107	total: 4.01s	remaining: 1m 15s
# 100:	learn: 0.5126028	total: 3.94s	remaining: 1m 14s
# 100:	learn: 0.5152577	total: 4.02s	remaining: 1m 15s
# 200:	learn: 0.5639981	total: 5.26s	remaining: 7.82s
# 200:	learn: 0.5606477	total: 5.11s	remaining: 7.6s
# 200:	learn: 0.5613688	total: 5.41s	remaining: 8.05s
# 200:	learn: 0.4391219	total: 7.63s	remaining: 1m 8s
# 300:	learn: 0.5146764	total: 7.58s	remaining: 5.01s
# 200:	learn: 0.4384866	total: 7.77s	remaining: 1m 9s
# 200:	learn: 0.4384335	total: 7.71s	remaining: 1m 8s
# 200:	learn: 0.4382665	total: 7.89s	remaining: 1m 10s
# 300:	learn: 0.5161968	total: 7.96s	remaining: 5.26s
# 300:	learn: 0.5136200	total: 7.95s	remaining: 5.26s
# 200:	learn: 0.4402127	total: 8.03s	remaining: 1m 11s
# 400:	learn: 0.4852942	total: 10.1s	remaining: 2.5s
# 400:	learn: 0.4854389	total: 10.5s	remaining: 2.58s
# 400:	learn: 0.4821419	total: 10.6s	remaining: 2.61s
# 300:	learn: 0.4021121	total: 11.6s	remaining: 1m 5s
# 300:	learn: 0.4024945	total: 11.6s	remaining: 1m 5s
# 300:	learn: 0.4013332	total: 11.8s	remaining: 1m 6s
# 300:	learn: 0.4015016	total: 11.7s	remaining: 1m 5s
# 300:	learn: 0.4038119	total: 11.9s	remaining: 1m 7s
# 499:	learn: 0.4625952	total: 12.7s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.05, rsm=1.0; total time=  12.9s
# 499:	learn: 0.4627851	total: 13s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.05, rsm=1.0; total time=  13.2s
# 0:	learn: 1.6071887	total: 28ms	remaining: 14s
# 0:	learn: 1.6086156	total: 41.6ms	remaining: 20.8s
# 499:	learn: 0.4591836	total: 13.2s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.05, rsm=1.0; total time=  13.4s
# 0:	learn: 1.6483156	total: 40.3ms	remaining: 40.2s
# 400:	learn: 0.3785754	total: 15.5s	remaining: 1m 1s
# 100:	learn: 0.6546120	total: 2.53s	remaining: 10s
# 400:	learn: 0.3788346	total: 15.7s	remaining: 1m 2s
# 400:	learn: 0.3806791	total: 15.7s	remaining: 1m 2s
# 400:	learn: 0.3787991	total: 15.6s	remaining: 1m 2s
# 100:	learn: 0.6555030	total: 2.72s	remaining: 10.7s
# 400:	learn: 0.3816484	total: 16s	remaining: 1m 3s
# 100:	learn: 1.0026737	total: 3.94s	remaining: 35.1s
# 200:	learn: 0.5611487	total: 5.64s	remaining: 8.4s
# 200:	learn: 0.5627026	total: 5.66s	remaining: 8.42s
# 500:	learn: 0.3625284	total: 19.4s	remaining: 58.1s
# 500:	learn: 0.3644305	total: 19.7s	remaining: 58.9s
# 500:	learn: 0.3625966	total: 19.6s	remaining: 58.6s
# 500:	learn: 0.3650565	total: 19.8s	remaining: 59.2s
# 500:	learn: 0.3631336	total: 19.9s	remaining: 59.6s
# 300:	learn: 0.5135816	total: 8.37s	remaining: 5.53s
# 300:	learn: 0.5157795	total: 8.43s	remaining: 5.57s
# 200:	learn: 0.7840808	total: 8.02s	remaining: 31.9s
# 600:	learn: 0.3497412	total: 23.6s	remaining: 55s
# 600:	learn: 0.3499960	total: 23.5s	remaining: 54.7s
# 600:	learn: 0.3514371	total: 23.7s	remaining: 55.2s
# 400:	learn: 0.4832292	total: 10.9s	remaining: 2.7s
# 600:	learn: 0.3508869	total: 24s	remaining: 56s
# 600:	learn: 0.3537437	total: 24s	remaining: 55.8s
# 400:	learn: 0.4848854	total: 11s	remaining: 2.71s
# 300:	learn: 0.6943719	total: 12s	remaining: 27.8s
# 499:	learn: 0.4608345	total: 13.6s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.05, rsm=1.0; total time=  13.8s
# 499:	learn: 0.4625725	total: 13.7s	remaining: 0us
# 0:	learn: 1.6475568	total: 40ms	remaining: 39.9s
# [CV] END bagging_temperature=0.8, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.05, rsm=1.0; total time=  13.9s
# 0:	learn: 1.6494569	total: 43.6ms	remaining: 43.5s
# 700:	learn: 0.3416880	total: 27.6s	remaining: 51.2s
# 700:	learn: 0.3398968	total: 27.5s	remaining: 50.9s
# 700:	learn: 0.3397580	total: 27.7s	remaining: 51.3s
# 700:	learn: 0.3433624	total: 27.9s	remaining: 51.6s
# 700:	learn: 0.3408977	total: 28.2s	remaining: 52.2s
# 400:	learn: 0.6424214	total: 16s	remaining: 23.9s
# 100:	learn: 1.0017476	total: 4.13s	remaining: 36.7s
# 100:	learn: 1.0008377	total: 4.14s	remaining: 36.9s
# 800:	learn: 0.3312664	total: 31.5s	remaining: 47.2s
# 800:	learn: 0.3330243	total: 31.7s	remaining: 47.5s
# 800:	learn: 0.3312356	total: 31.8s	remaining: 47.6s
# 800:	learn: 0.3346331	total: 32.1s	remaining: 48s
# 800:	learn: 0.3319466	total: 32.3s	remaining: 48.3s
# 500:	learn: 0.6076886	total: 20.1s	remaining: 20s
# 200:	learn: 0.7861821	total: 8.42s	remaining: 33.5s
# 200:	learn: 0.7852631	total: 8.47s	remaining: 33.7s
# 900:	learn: 0.3235854	total: 35.7s	remaining: 43.6s
# 900:	learn: 0.3255079	total: 35.9s	remaining: 43.8s
# 900:	learn: 0.3238172	total: 36.3s	remaining: 44.2s
# 900:	learn: 0.3266508	total: 36.4s	remaining: 44.4s
# 900:	learn: 0.3246202	total: 36.6s	remaining: 44.7s
# 600:	learn: 0.5822329	total: 24.6s	remaining: 16.3s
# 300:	learn: 0.6954610	total: 13.3s	remaining: 30.8s
# 300:	learn: 0.6917945	total: 13.2s	remaining: 30.6s
# 1000:	learn: 0.3167409	total: 40.5s	remaining: 40.4s
# 1000:	learn: 0.3184853	total: 40.8s	remaining: 40.7s
# 1000:	learn: 0.3171488	total: 41.1s	remaining: 41.1s
# 1000:	learn: 0.3200576	total: 41.2s	remaining: 41.1s
# 1000:	learn: 0.3180031	total: 41.4s	remaining: 41.3s
# 700:	learn: 0.5606992	total: 29.7s	remaining: 12.7s
# 400:	learn: 0.6419683	total: 18.4s	remaining: 27.4s
# 400:	learn: 0.6393256	total: 18.4s	remaining: 27.4s
# 1100:	learn: 0.3107245	total: 45.7s	remaining: 37.3s
# 1100:	learn: 0.3124834	total: 46s	remaining: 37.6s
# 1100:	learn: 0.3109899	total: 46.4s	remaining: 37.9s
# 1100:	learn: 0.3140515	total: 46.4s	remaining: 37.9s
# 1100:	learn: 0.3116900	total: 46.7s	remaining: 38.2s
# 800:	learn: 0.5434115	total: 35.2s	remaining: 8.75s
# 500:	learn: 0.6077988	total: 24.3s	remaining: 24.2s
# 500:	learn: 0.6051626	total: 24.2s	remaining: 24.1s
# 1200:	learn: 0.3051751	total: 51.4s	remaining: 34.2s
# 1200:	learn: 0.3065786	total: 52s	remaining: 34.6s
# 1200:	learn: 0.3057128	total: 52.4s	remaining: 34.8s
# 1200:	learn: 0.3083899	total: 52.5s	remaining: 34.9s
# 1200:	learn: 0.3061026	total: 52.7s	remaining: 35.1s
# 900:	learn: 0.5292480	total: 41.5s	remaining: 4.56s
# 600:	learn: 0.5826148	total: 30.9s	remaining: 20.5s
# 1300:	learn: 0.2999726	total: 57.9s	remaining: 31.1s
# 600:	learn: 0.5798708	total: 31.1s	remaining: 20.6s
# 1300:	learn: 0.3014550	total: 58.8s	remaining: 31.6s
# 1300:	learn: 0.3006337	total: 59.3s	remaining: 31.8s
# 1300:	learn: 0.3032719	total: 59.4s	remaining: 31.9s
# 1300:	learn: 0.3008684	total: 59.7s	remaining: 32.1s
# 999:	learn: 0.5171063	total: 48.7s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, rsm=0.8; total time=  49.1s
# 0:	learn: 1.6482880	total: 57.5ms	remaining: 57.4s
# 700:	learn: 0.5619994	total: 38.3s	remaining: 16.4s
# 1400:	learn: 0.2951014	total: 1m 5s	remaining: 27.9s
# 700:	learn: 0.5599006	total: 38.5s	remaining: 16.4s
# 1400:	learn: 0.2967935	total: 1m 6s	remaining: 28.4s
# 1400:	learn: 0.2959763	total: 1m 6s	remaining: 28.6s
# 1400:	learn: 0.2984891	total: 1m 7s	remaining: 28.7s
# 1400:	learn: 0.2961027	total: 1m 7s	remaining: 28.8s
# 100:	learn: 1.0032303	total: 7.6s	remaining: 1m 7s
# 800:	learn: 0.5442294	total: 45.9s	remaining: 11.4s
# 800:	learn: 0.5433868	total: 46.3s	remaining: 11.5s
# 1500:	learn: 0.2910216	total: 1m 13s	remaining: 24.4s
# 1500:	learn: 0.2921837	total: 1m 14s	remaining: 24.7s
# 1500:	learn: 0.2914355	total: 1m 14s	remaining: 24.9s
# 1500:	learn: 0.2939058	total: 1m 15s	remaining: 25s
# 1500:	learn: 0.2917219	total: 1m 15s	remaining: 25.1s
# 200:	learn: 0.7856684	total: 15.4s	remaining: 1m 1s
# 900:	learn: 0.5300711	total: 53.6s	remaining: 5.88s
# 900:	learn: 0.5287095	total: 54.1s	remaining: 5.94s
# 1600:	learn: 0.2868813	total: 1m 20s	remaining: 20.2s
# 1600:	learn: 0.2880144	total: 1m 21s	remaining: 20.4s
# 1600:	learn: 0.2873437	total: 1m 22s	remaining: 20.5s
# 1600:	learn: 0.2897427	total: 1m 22s	remaining: 20.6s
# 1600:	learn: 0.2874255	total: 1m 22s	remaining: 20.7s
# 300:	learn: 0.6942185	total: 23s	remaining: 53.5s
# 999:	learn: 0.5172220	total: 1m 1s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, rsm=0.8; total time= 1.0min
# 999:	learn: 0.5156741	total: 1m 1s	remaining: 0us
# 0:	learn: 1.6497087	total: 98.2ms	remaining: 1m 38s
# [CV] END bagging_temperature=0.8, depth=10, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, rsm=0.8; total time= 1.0min
# 1700:	learn: 0.2828763	total: 1m 28s	remaining: 15.6s
# 0:	learn: 1.6498456	total: 30ms	remaining: 30s
# 1700:	learn: 0.2838554	total: 1m 29s	remaining: 15.7s
# 1700:	learn: 0.2834676	total: 1m 30s	remaining: 15.8s
# 1700:	learn: 0.2833489	total: 1m 30s	remaining: 15.9s
# 1700:	learn: 0.2858048	total: 1m 30s	remaining: 15.9s
# 100:	learn: 1.0886616	total: 3.72s	remaining: 33.1s
# 400:	learn: 0.6419825	total: 30.4s	remaining: 45.4s
# 100:	learn: 1.0046313	total: 6.72s	remaining: 59.8s
# 1800:	learn: 0.2791162	total: 1m 35s	remaining: 10.6s
# 1800:	learn: 0.2799714	total: 1m 36s	remaining: 10.6s
# 200:	learn: 0.9063899	total: 7.16s	remaining: 28.5s
# 1800:	learn: 0.2798944	total: 1m 36s	remaining: 10.7s
# 1800:	learn: 0.2797873	total: 1m 37s	remaining: 10.8s
# 1800:	learn: 0.2820356	total: 1m 37s	remaining: 10.8s
# 500:	learn: 0.6078580	total: 36.6s	remaining: 36.5s
# 300:	learn: 0.8244065	total: 10.8s	remaining: 25.1s
# 200:	learn: 0.7868924	total: 13s	remaining: 51.9s
# 1900:	learn: 0.2756058	total: 1m 41s	remaining: 5.3s
# 1900:	learn: 0.2765216	total: 1m 42s	remaining: 5.34s
# 1900:	learn: 0.2763949	total: 1m 42s	remaining: 5.36s
# 1900:	learn: 0.2762105	total: 1m 43s	remaining: 5.4s
# 1900:	learn: 0.2784825	total: 1m 43s	remaining: 5.39s
# 400:	learn: 0.7688690	total: 14.5s	remaining: 21.6s
# 600:	learn: 0.5820717	total: 42.9s	remaining: 28.5s
# 500:	learn: 0.7308400	total: 17.8s	remaining: 17.8s
# 300:	learn: 0.6952564	total: 19.3s	remaining: 44.7s
# 1999:	learn: 0.2722812	total: 1m 47s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, rsm=0.8; total time= 1.8min
# 0:	learn: 1.6490441	total: 25.9ms	remaining: 25.9s
# 1999:	learn: 0.2732726	total: 1m 48s	remaining: 0us
# 1999:	learn: 0.2730365	total: 1m 48s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, rsm=0.8; total time= 1.8min
# [CV] END bagging_temperature=1, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, rsm=0.8; total time= 1.8min
# 0:	learn: 1.6509273	total: 58.3ms	remaining: 58.2s
# 0:	learn: 1.6497739	total: 30.9ms	remaining: 30.9s
# 1999:	learn: 0.2751695	total: 1m 49s	remaining: 0us
# 1999:	learn: 0.2730006	total: 1m 50s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, rsm=0.8; total time= 1.8min
# [CV] END bagging_temperature=1, depth=10, iterations=2000, l2_leaf_reg=5, learning_rate=0.1, rsm=0.8; total time= 1.8min
# 0:	learn: 1.6511968	total: 40.1ms	remaining: 40.1s
# 0:	learn: 1.6031061	total: 81.7ms	remaining: 1m 21s
# 600:	learn: 0.7020569	total: 21.6s	remaining: 14.4s
# 700:	learn: 0.5605902	total: 49.6s	remaining: 21.1s
# 100:	learn: 1.0873215	total: 3.77s	remaining: 33.6s
# 100:	learn: 1.0887191	total: 3.4s	remaining: 30.3s
# 100:	learn: 1.0871478	total: 3.58s	remaining: 31.9s
# 100:	learn: 1.0905380	total: 3.22s	remaining: 28.7s
# 700:	learn: 0.6799312	total: 24.7s	remaining: 10.5s
# 400:	learn: 0.6430246	total: 25.7s	remaining: 38.3s
# 200:	learn: 0.9063669	total: 6.29s	remaining: 25s
# 200:	learn: 0.9036192	total: 6.45s	remaining: 25.6s
# 200:	learn: 0.9041511	total: 7.26s	remaining: 28.9s
# 100:	learn: 0.6044689	total: 5.5s	remaining: 48.9s
# 800:	learn: 0.6623374	total: 27.5s	remaining: 6.83s
# 200:	learn: 0.9060062	total: 6.93s	remaining: 27.5s
# 800:	learn: 0.5437257	total: 54.8s	remaining: 13.6s
# 300:	learn: 0.8240211	total: 9.1s	remaining: 21.1s
# 300:	learn: 0.8226537	total: 9.21s	remaining: 21.4s
# 300:	learn: 0.8225050	total: 10.5s	remaining: 24.3s
# 900:	learn: 0.6463718	total: 30.4s	remaining: 3.34s
# 500:	learn: 0.6083288	total: 30.8s	remaining: 30.7s
# 300:	learn: 0.8235089	total: 10.1s	remaining: 23.3s
# 200:	learn: 0.5160257	total: 11.1s	remaining: 44s
# 400:	learn: 0.7701086	total: 12.3s	remaining: 18.4s
# 400:	learn: 0.7722745	total: 12.3s	remaining: 18.4s
# 400:	learn: 0.7686462	total: 13.6s	remaining: 20.3s
# 999:	learn: 0.6328535	total: 33.5s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time=  33.7s
# 900:	learn: 0.5287008	total: 1m	remaining: 6.63s
# 0:	learn: 1.6028180	total: 55ms	remaining: 54.9s
# 400:	learn: 0.7700705	total: 13s	remaining: 19.5s
# 500:	learn: 0.7310356	total: 15.4s	remaining: 15.3s
# 500:	learn: 0.7328530	total: 15.4s	remaining: 15.3s
# 600:	learn: 0.5829223	total: 36.3s	remaining: 24.1s
# 500:	learn: 0.7316597	total: 16.6s	remaining: 16.6s
# 500:	learn: 0.7320504	total: 15.9s	remaining: 15.9s
# 300:	learn: 0.4680175	total: 16.5s	remaining: 38.4s
# 600:	learn: 0.7023556	total: 18.5s	remaining: 12.3s
# 600:	learn: 0.7035276	total: 18.4s	remaining: 12.2s
# 600:	learn: 0.7018217	total: 19.7s	remaining: 13.1s
# 100:	learn: 0.6054225	total: 5.49s	remaining: 48.8s
# 999:	learn: 0.5159175	total: 1m 5s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, rsm=0.8; total time= 1.1min
# 0:	learn: 1.6045950	total: 60.6ms	remaining: 1m
# 600:	learn: 0.7021580	total: 19.4s	remaining: 12.9s
# 700:	learn: 0.5625801	total: 43s	remaining: 18.3s
# 700:	learn: 0.6790760	total: 22.7s	remaining: 9.68s
# 700:	learn: 0.6822028	total: 23s	remaining: 9.8s
# 700:	learn: 0.6795047	total: 23.9s	remaining: 10.2s
# 400:	learn: 0.4378235	total: 23.3s	remaining: 34.7s
# 700:	learn: 0.6790895	total: 23.4s	remaining: 9.99s
# 200:	learn: 0.5166257	total: 12.1s	remaining: 48.3s
# 800:	learn: 0.6611999	total: 25.6s	remaining: 6.36s
# 800:	learn: 0.6623455	total: 26.6s	remaining: 6.6s
# 100:	learn: 0.6092403	total: 6.59s	remaining: 58.6s
# 800:	learn: 0.6637530	total: 25.8s	remaining: 6.41s
# 800:	learn: 0.6610473	total: 26.3s	remaining: 6.52s
# 800:	learn: 0.5462569	total: 48.2s	remaining: 12s
# 900:	learn: 0.6445946	total: 28.5s	remaining: 3.14s
# 900:	learn: 0.6478446	total: 28.6s	remaining: 3.15s
# 900:	learn: 0.6462627	total: 29.6s	remaining: 3.25s
# 500:	learn: 0.4163000	total: 28.3s	remaining: 28.2s
# 900:	learn: 0.6457963	total: 29.1s	remaining: 3.2s
# 300:	learn: 0.4684944	total: 17.2s	remaining: 39.8s
# 200:	learn: 0.5155299	total: 12.1s	remaining: 48s
# 999:	learn: 0.6311174	total: 32.1s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time=  32.4s
# 999:	learn: 0.6346422	total: 32.3s	remaining: 0us
# 0:	learn: 1.6035809	total: 91ms	remaining: 1m 30s
# [CV] END bagging_temperature=0.8, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time=  32.7s
# 999:	learn: 0.6329677	total: 33.4s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time=  33.7s
# 0:	learn: 1.6049846	total: 68.5ms	remaining: 1m 8s
# 0:	learn: 1.5612079	total: 48.2ms	remaining: 1m 36s
# 900:	learn: 0.5320018	total: 54.5s	remaining: 5.99s
# 999:	learn: 0.6334110	total: 33.4s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time=  33.7s
# 0:	learn: 1.5602872	total: 23.8ms	remaining: 47.6s
# 600:	learn: 0.4008678	total: 35.2s	remaining: 23.4s
# 100:	learn: 0.6293215	total: 3.49s	remaining: 1m 5s
# 100:	learn: 0.6297247	total: 3.06s	remaining: 57.5s
# 400:	learn: 0.4382766	total: 24.2s	remaining: 36.2s
# 300:	learn: 0.4664311	total: 18.8s	remaining: 43.7s
# 100:	learn: 0.6056931	total: 6.17s	remaining: 55s
# 100:	learn: 0.6097396	total: 6.36s	remaining: 56.6s
# 200:	learn: 0.5467136	total: 6.52s	remaining: 58.3s
# 999:	learn: 0.5189273	total: 1m	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=1000, l2_leaf_reg=5, learning_rate=0.01, rsm=0.8; total time= 1.0min
# 0:	learn: 1.5616840	total: 21.2ms	remaining: 42.3s
# 200:	learn: 0.5490511	total: 5.98s	remaining: 53.6s
# 700:	learn: 0.3881114	total: 41s	remaining: 17.5s
# 300:	learn: 0.5053361	total: 9.81s	remaining: 55.4s
# 100:	learn: 0.6267000	total: 3.14s	remaining: 59.1s
# 500:	learn: 0.4168855	total: 29.9s	remaining: 29.8s
# 400:	learn: 0.4367155	total: 24.6s	remaining: 36.8s
# 300:	learn: 0.5048493	total: 9.34s	remaining: 52.7s
# 200:	learn: 0.5156054	total: 11.9s	remaining: 47.2s
# 200:	learn: 0.5187117	total: 12.2s	remaining: 48.3s
# 400:	learn: 0.4764656	total: 12.8s	remaining: 51.1s
# 200:	learn: 0.5473349	total: 6.11s	remaining: 54.7s
# 400:	learn: 0.4782964	total: 12.1s	remaining: 48.4s
# 800:	learn: 0.3777648	total: 46.7s	remaining: 11.6s
# 500:	learn: 0.4574846	total: 15.8s	remaining: 47.1s
# 600:	learn: 0.4004252	total: 35.5s	remaining: 23.5s
# 300:	learn: 0.5062158	total: 9.19s	remaining: 51.9s
# 500:	learn: 0.4151278	total: 29.9s	remaining: 29.8s
# 300:	learn: 0.4693372	total: 17.3s	remaining: 40.3s
# 500:	learn: 0.4588130	total: 15.3s	remaining: 45.7s
# 300:	learn: 0.4713613	total: 18s	remaining: 41.9s
# 600:	learn: 0.4435186	total: 18.9s	remaining: 44s
# 400:	learn: 0.4776490	total: 12.3s	remaining: 49.2s
# 600:	learn: 0.4435337	total: 18.2s	remaining: 42.3s
# 900:	learn: 0.3687379	total: 52.3s	remaining: 5.74s
# 700:	learn: 0.3875618	total: 41s	remaining: 17.5s
# 600:	learn: 0.3993101	total: 35.2s	remaining: 23.4s
# 700:	learn: 0.4321793	total: 21.7s	remaining: 40.3s
# 400:	learn: 0.4377322	total: 22.5s	remaining: 33.6s
# 500:	learn: 0.4585699	total: 15.2s	remaining: 45.6s
# 400:	learn: 0.4405968	total: 23.2s	remaining: 34.7s
# 700:	learn: 0.4320695	total: 21.5s	remaining: 39.8s
# 800:	learn: 0.4228805	total: 24.7s	remaining: 37s
# 600:	learn: 0.4437098	total: 18.3s	remaining: 42.5s
# 999:	learn: 0.3614441	total: 57.8s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, rsm=0.8; total time=  58.2s
# 800:	learn: 0.4229306	total: 24.5s	remaining: 36.6s
# 0:	learn: 1.5611506	total: 40.7ms	remaining: 1m 21s
# 800:	learn: 0.3775415	total: 46.6s	remaining: 11.6s
# 700:	learn: 0.3869105	total: 40.8s	remaining: 17.4s
# 500:	learn: 0.4155707	total: 27.8s	remaining: 27.7s
# 900:	learn: 0.4141756	total: 27.6s	remaining: 33.7s
# 700:	learn: 0.4326457	total: 21.2s	remaining: 39.4s
# 500:	learn: 0.4200809	total: 28.5s	remaining: 28.4s
# 100:	learn: 0.6274977	total: 2.8s	remaining: 52.6s
# 900:	learn: 0.4142077	total: 27.6s	remaining: 33.7s
# 1000:	learn: 0.4075220	total: 30.6s	remaining: 30.6s
# 800:	learn: 0.4227829	total: 24.1s	remaining: 36s
# 200:	learn: 0.5482324	total: 5.79s	remaining: 51.8s
# 1000:	learn: 0.4072415	total: 30.5s	remaining: 30.5s
# 900:	learn: 0.3686892	total: 52s	remaining: 5.72s
# 800:	learn: 0.3768608	total: 46.2s	remaining: 11.5s
# 600:	learn: 0.3998295	total: 33.3s	remaining: 22.1s
# 1100:	learn: 0.4013832	total: 33.5s	remaining: 27.4s
# 600:	learn: 0.4040078	total: 34s	remaining: 22.6s
# 900:	learn: 0.4148269	total: 27.2s	remaining: 33.2s
# 300:	learn: 0.5079105	total: 8.78s	remaining: 49.6s
# 1100:	learn: 0.4013837	total: 33.4s	remaining: 27.3s
# 1200:	learn: 0.3959640	total: 36.7s	remaining: 24.4s
# 1000:	learn: 0.4070773	total: 30.2s	remaining: 30.1s
# 400:	learn: 0.4801326	total: 11.6s	remaining: 46.2s
# 999:	learn: 0.3612824	total: 57.4s	remaining: 0us
# 1200:	learn: 0.3961904	total: 36.2s	remaining: 24.1s
# [CV] END bagging_temperature=1, depth=10, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, rsm=0.8; total time=  57.7s
# 900:	learn: 0.3683899	total: 51.7s	remaining: 5.68s
# 0:	learn: 1.5625891	total: 29.1ms	remaining: 58.2s
# 700:	learn: 0.3869377	total: 38.7s	remaining: 16.5s
# 700:	learn: 0.3906672	total: 39.2s	remaining: 16.7s
# 1300:	learn: 0.3915374	total: 39.5s	remaining: 21.2s
# 1100:	learn: 0.4007548	total: 33.1s	remaining: 27.1s
# 500:	learn: 0.4601099	total: 14.7s	remaining: 43.9s
# 1300:	learn: 0.3916048	total: 39.3s	remaining: 21.1s
# 100:	learn: 0.6303519	total: 3.07s	remaining: 57.7s
# 1400:	learn: 0.3874974	total: 42.4s	remaining: 18.1s
# 1200:	learn: 0.3953692	total: 36s	remaining: 24s
# 999:	learn: 0.3608432	total: 57s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, rsm=0.8; total time=  57.3s
# 0:	learn: 1.6482860	total: 61.9ms	remaining: 2m 3s
# 600:	learn: 0.4455524	total: 17.5s	remaining: 40.7s
# 800:	learn: 0.3766432	total: 44.2s	remaining: 11s
# 1400:	learn: 0.3872997	total: 42.1s	remaining: 18s
# 200:	learn: 0.5487136	total: 5.92s	remaining: 53s
# 800:	learn: 0.3802181	total: 44.5s	remaining: 11.1s
# 1500:	learn: 0.3836127	total: 45.2s	remaining: 15s
# 1300:	learn: 0.3906802	total: 38.8s	remaining: 20.9s
# 700:	learn: 0.4337317	total: 20.4s	remaining: 37.8s
# 1500:	learn: 0.3836408	total: 45.1s	remaining: 15s
# 300:	learn: 0.5053394	total: 9s	remaining: 50.8s
# 1600:	learn: 0.3801199	total: 48.1s	remaining: 12s
# 1400:	learn: 0.3866597	total: 41.7s	remaining: 17.8s
# 100:	learn: 1.0003384	total: 5.41s	remaining: 1m 41s
# 900:	learn: 0.3679322	total: 49.8s	remaining: 5.47s
# 1600:	learn: 0.3801512	total: 47.8s	remaining: 11.9s
# 800:	learn: 0.4234219	total: 23.4s	remaining: 35s
# 900:	learn: 0.3716833	total: 49.9s	remaining: 5.49s
# 400:	learn: 0.4788749	total: 11.9s	remaining: 47.5s
# 1700:	learn: 0.3768595	total: 51s	remaining: 8.96s
# 1500:	learn: 0.3831043	total: 44.5s	remaining: 14.8s
# 1700:	learn: 0.3770718	total: 50.7s	remaining: 8.9s
# 900:	learn: 0.4151166	total: 26.3s	remaining: 32.1s
# 500:	learn: 0.4598080	total: 14.9s	remaining: 44.5s
# 200:	learn: 0.7835355	total: 10.3s	remaining: 1m 32s
# 1800:	learn: 0.3738961	total: 53.8s	remaining: 5.94s
# 1600:	learn: 0.3795323	total: 47.2s	remaining: 11.8s
# 999:	learn: 0.3605092	total: 54.8s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, rsm=0.8; total time=  55.2s
# 0:	learn: 1.6475258	total: 42.1ms	remaining: 1m 24s
# 999:	learn: 0.3638867	total: 55s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, rsm=0.8; total time=  55.5s
# 0:	learn: 1.6494260	total: 38.2ms	remaining: 1m 16s
# 1800:	learn: 0.3741816	total: 53.5s	remaining: 5.91s
# 1000:	learn: 0.4080222	total: 29.1s	remaining: 29s
# 600:	learn: 0.4456369	total: 17.8s	remaining: 41.5s
# 1700:	learn: 0.3763844	total: 49.8s	remaining: 8.75s
# 1900:	learn: 0.3711340	total: 56.9s	remaining: 2.96s
# 1900:	learn: 0.3712124	total: 56.3s	remaining: 2.93s
# 300:	learn: 0.6935392	total: 14.6s	remaining: 1m 22s
# 100:	learn: 1.0005953	total: 4.25s	remaining: 1m 19s
# 1100:	learn: 0.4017899	total: 32.6s	remaining: 26.6s
# 1800:	learn: 0.3735400	total: 52.1s	remaining: 5.76s
# 100:	learn: 1.0004255	total: 4.26s	remaining: 1m 20s
# 700:	learn: 0.4345262	total: 21.5s	remaining: 39.8s
# 1999:	learn: 0.3685714	total: 1m	remaining: 0us
# [CV] END bagging_temperature=1, depth=6, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, rsm=1.0; total time= 1.0min
# 1999:	learn: 0.3686443	total: 59.2s	remaining: 0us
# 0:	learn: 1.6482571	total: 84.1ms	remaining: 2m 48s
# [CV] END bagging_temperature=1, depth=6, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, rsm=1.0; total time=  59.6s
# 0:	learn: 1.6496779	total: 50.8ms	remaining: 1m 41s
# 1200:	learn: 0.3962441	total: 35.8s	remaining: 23.8s
# 1900:	learn: 0.3703169	total: 55.3s	remaining: 2.88s
# 800:	learn: 0.4249196	total: 24.5s	remaining: 36.7s
# 400:	learn: 0.6414694	total: 20.2s	remaining: 1m 20s
# 200:	learn: 0.7830380	total: 10s	remaining: 1m 29s
# 200:	learn: 0.7850019	total: 9.89s	remaining: 1m 28s
# 1300:	learn: 0.3917156	total: 38.8s	remaining: 20.8s
# 1999:	learn: 0.3676649	total: 58.2s	remaining: 0us
# [CV] END bagging_temperature=1, depth=6, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, rsm=1.0; total time=  58.6s
# 0:	learn: 1.5475177	total: 60.7ms	remaining: 30.3s
# 900:	learn: 0.4167033	total: 27.6s	remaining: 33.7s
# 100:	learn: 1.0005093	total: 5.67s	remaining: 1m 46s
# 100:	learn: 1.0012435	total: 5.79s	remaining: 1m 48s
# 1400:	learn: 0.3873840	total: 41.8s	remaining: 17.9s
# 1000:	learn: 0.4090089	total: 30.7s	remaining: 30.6s
# 500:	learn: 0.6077219	total: 25.6s	remaining: 1m 16s
# 300:	learn: 0.6928105	total: 15.4s	remaining: 1m 26s
# 300:	learn: 0.6924755	total: 15.2s	remaining: 1m 25s
# 100:	learn: 0.5148927	total: 5.45s	remaining: 21.5s
# 1500:	learn: 0.3837982	total: 44.8s	remaining: 14.9s
# 1100:	learn: 0.4035500	total: 33.4s	remaining: 27.3s
# 200:	learn: 0.7821343	total: 10.7s	remaining: 1m 35s
# 200:	learn: 0.7849629	total: 10.9s	remaining: 1m 37s
# 1600:	learn: 0.3801414	total: 47.6s	remaining: 11.9s
# 600:	learn: 0.5822394	total: 31s	remaining: 1m 12s
# 1200:	learn: 0.3980856	total: 36.4s	remaining: 24.2s
# 400:	learn: 0.6417272	total: 21.4s	remaining: 1m 25s
# 400:	learn: 0.6400680	total: 21.5s	remaining: 1m 25s
# 200:	learn: 0.4363366	total: 11.9s	remaining: 17.7s
# 1700:	learn: 0.3769709	total: 51.6s	remaining: 9.08s
# 300:	learn: 0.6931665	total: 17.4s	remaining: 1m 38s
# 1300:	learn: 0.3935763	total: 40.5s	remaining: 21.8s
# 300:	learn: 0.6971966	total: 17.6s	remaining: 1m 39s
# 1800:	learn: 0.3741161	total: 54.6s	remaining: 6.03s
# 700:	learn: 0.5606971	total: 37.7s	remaining: 1m 9s
# 1400:	learn: 0.3894884	total: 43.3s	remaining: 18.5s
# 500:	learn: 0.6064306	total: 27.2s	remaining: 1m 21s
# 500:	learn: 0.6049815	total: 27.3s	remaining: 1m 21s
# 300:	learn: 0.3998799	total: 17.3s	remaining: 11.5s
# 400:	learn: 0.6400306	total: 22.7s	remaining: 1m 30s
# 1900:	learn: 0.3712266	total: 57.5s	remaining: 3s
# 400:	learn: 0.6442703	total: 22.8s	remaining: 1m 30s
# 1500:	learn: 0.3855332	total: 46.3s	remaining: 15.4s
# 800:	learn: 0.5432446	total: 43s	remaining: 1m 4s
# 1999:	learn: 0.3688117	total: 1m	remaining: 0us
# [CV] END bagging_temperature=1, depth=6, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, rsm=1.0; total time= 1.0min
# 0:	learn: 1.5478280	total: 65.5ms	remaining: 32.7s
# 600:	learn: 0.5809044	total: 32.7s	remaining: 1m 16s
# 1600:	learn: 0.3819700	total: 49.3s	remaining: 12.3s
# 600:	learn: 0.5793548	total: 32.8s	remaining: 1m 16s
# 400:	learn: 0.3772648	total: 22.9s	remaining: 5.65s
# 500:	learn: 0.6070586	total: 28.1s	remaining: 1m 24s
# 500:	learn: 0.6095588	total: 28.1s	remaining: 1m 23s
# 1700:	learn: 0.3788293	total: 52.2s	remaining: 9.17s
# 900:	learn: 0.5284687	total: 48.5s	remaining: 59.2s
# 100:	learn: 0.5132524	total: 5.52s	remaining: 21.8s
# 700:	learn: 0.5599163	total: 38.2s	remaining: 1m 10s
# 700:	learn: 0.5588219	total: 38.1s	remaining: 1m 10s
# 1800:	learn: 0.3758802	total: 55.2s	remaining: 6.09s
# 499:	learn: 0.3614692	total: 28.2s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=3, learning_rate=0.1, rsm=0.8; total time=  28.4s
# 0:	learn: 1.5494506	total: 53.5ms	remaining: 26.7s
# 600:	learn: 0.5801621	total: 33.6s	remaining: 1m 18s
# 600:	learn: 0.5832006	total: 33.4s	remaining: 1m 17s
# 1900:	learn: 0.3732354	total: 57.9s	remaining: 3.02s
# 1000:	learn: 0.5153410	total: 54s	remaining: 53.9s
# 800:	learn: 0.5434863	total: 43.6s	remaining: 1m 5s
# 200:	learn: 0.4366638	total: 11.1s	remaining: 16.5s
# 800:	learn: 0.5414949	total: 43.5s	remaining: 1m 5s
# 100:	learn: 0.5127747	total: 5.21s	remaining: 20.6s
# 1999:	learn: 0.3706502	total: 1m	remaining: 0us
# [CV] END bagging_temperature=1, depth=6, iterations=2000, l2_leaf_reg=3, learning_rate=0.1, rsm=1.0; total time= 1.0min
# 0:	learn: 1.5486318	total: 50ms	remaining: 24.9s
# 700:	learn: 0.5591604	total: 39s	remaining: 1m 12s
# 700:	learn: 0.5624720	total: 38.8s	remaining: 1m 11s
# 1100:	learn: 0.5040929	total: 59.5s	remaining: 48.5s
# 900:	learn: 0.5287414	total: 48.9s	remaining: 59.7s
# 300:	learn: 0.4005305	total: 16.7s	remaining: 11s
# 900:	learn: 0.5269021	total: 49.1s	remaining: 59.9s
# 100:	learn: 0.5153134	total: 5.49s	remaining: 21.7s
# 200:	learn: 0.4359878	total: 11.1s	remaining: 16.5s
# 800:	learn: 0.5420726	total: 44.5s	remaining: 1m 6s
# 800:	learn: 0.5452668	total: 44.3s	remaining: 1m 6s
# 1200:	learn: 0.4936242	total: 1m 4s	remaining: 43.2s
# 1000:	learn: 0.5154161	total: 54.3s	remaining: 54.2s
# 400:	learn: 0.3768419	total: 22.2s	remaining: 5.48s
# 1000:	learn: 0.5136559	total: 54.5s	remaining: 54.4s
# 300:	learn: 0.3992250	total: 16.5s	remaining: 10.9s
# 200:	learn: 0.4375387	total: 11.1s	remaining: 16.5s
# 900:	learn: 0.5272981	total: 49.9s	remaining: 1m
# 900:	learn: 0.5308854	total: 49.7s	remaining: 1m
# 1300:	learn: 0.4842264	total: 1m 10s	remaining: 37.8s
# 1100:	learn: 0.5040293	total: 59.7s	remaining: 48.7s
# 499:	learn: 0.3609248	total: 27.6s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=3, learning_rate=0.1, rsm=0.8; total time=  27.8s
# 1100:	learn: 0.5022526	total: 59.9s	remaining: 48.9s
# 0:	learn: 1.5500155	total: 60.7ms	remaining: 30.3s
# 400:	learn: 0.3760787	total: 21.8s	remaining: 5.39s
# 300:	learn: 0.4006555	total: 16.5s	remaining: 10.9s
# 1000:	learn: 0.5142827	total: 55.3s	remaining: 55.2s
# 1000:	learn: 0.5174251	total: 55.1s	remaining: 55s
# 1400:	learn: 0.4757007	total: 1m 15s	remaining: 32.4s
# 1200:	learn: 0.4935594	total: 1m 5s	remaining: 43.3s
# 100:	learn: 0.5194642	total: 5.26s	remaining: 20.8s
# 1200:	learn: 0.4916176	total: 1m 5s	remaining: 43.5s
# 499:	learn: 0.3599165	total: 27.3s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=3, learning_rate=0.1, rsm=0.8; total time=  27.5s
# 400:	learn: 0.3778885	total: 22s	remaining: 5.42s
# 0:	learn: 1.6042540	total: 51ms	remaining: 1m 41s
# 1100:	learn: 0.5036853	total: 1m	remaining: 49.6s
# 1100:	learn: 0.5055936	total: 1m	remaining: 49.5s
# 1500:	learn: 0.4680157	total: 1m 21s	remaining: 27.1s
# 1300:	learn: 0.4843388	total: 1m 10s	remaining: 37.9s
# 200:	learn: 0.4416253	total: 10.7s	remaining: 15.9s
# 1300:	learn: 0.4826817	total: 1m 11s	remaining: 38.2s
# 499:	learn: 0.3614645	total: 27.2s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=3, learning_rate=0.1, rsm=0.8; total time=  27.4s
# 0:	learn: 1.6033714	total: 62.7ms	remaining: 2m 5s
# 1200:	learn: 0.4928492	total: 1m 6s	remaining: 44s
# 100:	learn: 0.5993201	total: 5.92s	remaining: 1m 51s
# 1200:	learn: 0.4950693	total: 1m 6s	remaining: 43.9s
# 1600:	learn: 0.4610654	total: 1m 26s	remaining: 21.6s
# 1400:	learn: 0.4757778	total: 1m 15s	remaining: 32.5s
# 300:	learn: 0.4034298	total: 16s	remaining: 10.6s
# 1400:	learn: 0.4743688	total: 1m 16s	remaining: 32.7s
# 1300:	learn: 0.4833452	total: 1m 11s	remaining: 38.3s
# 1300:	learn: 0.4861890	total: 1m 11s	remaining: 38.3s
# 100:	learn: 0.6017170	total: 5.9s	remaining: 1m 50s
# 200:	learn: 0.5086632	total: 11.8s	remaining: 1m 45s
# 1700:	learn: 0.4547211	total: 1m 32s	remaining: 16.2s
# 1500:	learn: 0.4680251	total: 1m 21s	remaining: 27.1s
# 400:	learn: 0.3808858	total: 21.7s	remaining: 5.36s
# 1500:	learn: 0.4665356	total: 1m 22s	remaining: 27.4s
# 1400:	learn: 0.4749935	total: 1m 17s	remaining: 33s
# 1400:	learn: 0.4774374	total: 1m 16s	remaining: 32.9s
# 200:	learn: 0.5101486	total: 12.2s	remaining: 1m 49s
# 300:	learn: 0.4629979	total: 18.3s	remaining: 1m 43s
# 1800:	learn: 0.4485318	total: 1m 37s	remaining: 10.8s
# 1600:	learn: 0.4609702	total: 1m 27s	remaining: 21.7s
# 499:	learn: 0.3639695	total: 27.2s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=3, learning_rate=0.1, rsm=0.8; total time=  27.4s
# 0:	learn: 1.6050342	total: 64.7ms	remaining: 2m 9s
# 1600:	learn: 0.4594615	total: 1m 28s	remaining: 22s
# 1500:	learn: 0.4673272	total: 1m 22s	remaining: 27.6s
# 1500:	learn: 0.4694220	total: 1m 22s	remaining: 27.6s
# 300:	learn: 0.4634704	total: 18.9s	remaining: 1m 46s
# 400:	learn: 0.4335339	total: 24.9s	remaining: 1m 39s
# 1900:	learn: 0.4430218	total: 1m 44s	remaining: 5.42s
# 1700:	learn: 0.4544463	total: 1m 33s	remaining: 16.5s
# 100:	learn: 0.5975640	total: 6.92s	remaining: 2m 10s
# 1700:	learn: 0.4531588	total: 1m 34s	remaining: 16.6s
# 1600:	learn: 0.4599923	total: 1m 29s	remaining: 22.2s
# 1600:	learn: 0.4623328	total: 1m 29s	remaining: 22.2s
# 400:	learn: 0.4339184	total: 25.3s	remaining: 1m 41s
# 500:	learn: 0.4120432	total: 31.3s	remaining: 1m 33s
# 1999:	learn: 0.4380029	total: 1m 49s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=2000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time= 1.8min
# 0:	learn: 1.6040834	total: 58.9ms	remaining: 1m 57s
# 1800:	learn: 0.4482979	total: 1m 39s	remaining: 10.9s
# 1800:	learn: 0.4471375	total: 1m 39s	remaining: 11s
# 200:	learn: 0.5101294	total: 13.2s	remaining: 1m 58s
# 1700:	learn: 0.4535369	total: 1m 34s	remaining: 16.6s
# 1700:	learn: 0.4560468	total: 1m 34s	remaining: 16.7s
# 500:	learn: 0.4137380	total: 31.7s	remaining: 1m 34s
# 600:	learn: 0.3963829	total: 37.9s	remaining: 1m 28s
# 1900:	learn: 0.4426699	total: 1m 44s	remaining: 5.47s
# 100:	learn: 0.6036953	total: 6.78s	remaining: 2m 7s
# 1900:	learn: 0.4416861	total: 1m 46s	remaining: 5.53s
# 1800:	learn: 0.4475761	total: 1m 40s	remaining: 11.1s
# 300:	learn: 0.4620921	total: 19.8s	remaining: 1m 51s
# 1800:	learn: 0.4501312	total: 1m 40s	remaining: 11.1s
# 600:	learn: 0.3973756	total: 38.1s	remaining: 1m 28s
# 1999:	learn: 0.4375395	total: 1m 50s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=2000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time= 1.9min
# 700:	learn: 0.3839961	total: 44.4s	remaining: 1m 22s
# 0:	learn: 1.6055285	total: 71.8ms	remaining: 2m 23s
# 200:	learn: 0.5116976	total: 13s	remaining: 1m 56s
# 1999:	learn: 0.4366124	total: 1m 51s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=2000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time= 1.9min
# 0:	learn: 1.5472227	total: 57.5ms	remaining: 28.7s
# 1900:	learn: 0.4420979	total: 1m 46s	remaining: 5.54s
# 1900:	learn: 0.4447043	total: 1m 46s	remaining: 5.55s
# 400:	learn: 0.4330787	total: 26.4s	remaining: 1m 45s
# 700:	learn: 0.3842882	total: 44.4s	remaining: 1m 22s
# 100:	learn: 0.5999498	total: 6.33s	remaining: 1m 59s
# 800:	learn: 0.3736555	total: 50.9s	remaining: 1m 16s
# 100:	learn: 0.5142907	total: 5.66s	remaining: 22.4s
# 1999:	learn: 0.4369819	total: 1m 52s	remaining: 0us
# 300:	learn: 0.4637113	total: 19.4s	remaining: 1m 49s
# [CV] END bagging_temperature=1, depth=10, iterations=2000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time= 1.9min
# 0:	learn: 1.5475193	total: 60ms	remaining: 30s
# 1999:	learn: 0.4397746	total: 1m 52s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=2000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time= 1.9min
# 0:	learn: 1.5491430	total: 50.6ms	remaining: 25.2s
# 500:	learn: 0.4128969	total: 32.9s	remaining: 1m 38s
# 800:	learn: 0.3737209	total: 50.8s	remaining: 1m 16s
# 200:	learn: 0.5103479	total: 12.6s	remaining: 1m 53s
# 900:	learn: 0.3646992	total: 57.3s	remaining: 1m 9s
# 200:	learn: 0.4338689	total: 11.6s	remaining: 17.2s
# 100:	learn: 0.5122396	total: 5.85s	remaining: 23.1s
# 400:	learn: 0.4336102	total: 25.8s	remaining: 1m 42s
# 100:	learn: 0.5102646	total: 5.96s	remaining: 23.5s
# 600:	learn: 0.3969005	total: 39.2s	remaining: 1m 31s
# 900:	learn: 0.3642037	total: 56.8s	remaining: 1m 9s
# 300:	learn: 0.3983213	total: 17.1s	remaining: 11.3s
# 300:	learn: 0.4629128	total: 18.7s	remaining: 1m 45s
# 1000:	learn: 0.3569135	total: 1m 3s	remaining: 1m 3s
# 200:	learn: 0.4346293	total: 11.6s	remaining: 17.2s
# 500:	learn: 0.4124206	total: 32s	remaining: 1m 35s
# 200:	learn: 0.4337302	total: 11.6s	remaining: 17.3s
# 700:	learn: 0.3843519	total: 45.4s	remaining: 1m 24s
# 1000:	learn: 0.3569465	total: 1m 2s	remaining: 1m 2s
# 400:	learn: 0.3746682	total: 22.8s	remaining: 5.64s
# 300:	learn: 0.3971441	total: 17.3s	remaining: 11.4s
# 400:	learn: 0.4339303	total: 24.9s	remaining: 1m 39s
# 1100:	learn: 0.3501862	total: 1m 9s	remaining: 56.9s
# 300:	learn: 0.3975143	total: 17.2s	remaining: 11.4s
# 600:	learn: 0.3962660	total: 38.1s	remaining: 1m 28s
# 800:	learn: 0.3738180	total: 51.7s	remaining: 1m 17s
# 499:	learn: 0.3585599	total: 28.4s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=1, learning_rate=0.1, rsm=0.8; total time=  28.6s
# 1100:	learn: 0.3500782	total: 1m 8s	remaining: 56.3s
# 0:	learn: 1.5483249	total: 56.2ms	remaining: 28.1s
# 400:	learn: 0.3746038	total: 22.9s	remaining: 5.65s
# 500:	learn: 0.4130934	total: 31s	remaining: 1m 32s
# 400:	learn: 0.3741710	total: 22.9s	remaining: 5.65s
# 1200:	learn: 0.3438055	total: 1m 15s	remaining: 50.4s
# 700:	learn: 0.3836858	total: 44.3s	remaining: 1m 22s
# 900:	learn: 0.3645117	total: 57.7s	remaining: 1m 10s
# 100:	learn: 0.5105536	total: 5.6s	remaining: 22.1s
# 499:	learn: 0.3584274	total: 28.3s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=1, learning_rate=0.1, rsm=0.8; total time=  28.5s
# 1200:	learn: 0.3438216	total: 1m 15s	remaining: 50s
# 0:	learn: 1.5497083	total: 51.4ms	remaining: 25.6s
# 499:	learn: 0.3577451	total: 28.5s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=1, learning_rate=0.1, rsm=0.8; total time=  28.7s
# 600:	learn: 0.3977825	total: 37.4s	remaining: 1m 27s
# 0:	learn: 1.6043442	total: 70.5ms	remaining: 35.2s
# 1300:	learn: 0.3381365	total: 1m 22s	remaining: 44.1s
# 800:	learn: 0.3729448	total: 50.6s	remaining: 1m 15s
# 1000:	learn: 0.3566967	total: 1m 4s	remaining: 1m 4s
# 200:	learn: 0.4337660	total: 11.4s	remaining: 16.9s
# 100:	learn: 0.5131119	total: 6.14s	remaining: 24.3s
# 1300:	learn: 0.3381498	total: 1m 21s	remaining: 43.8s
# 700:	learn: 0.3850855	total: 43.9s	remaining: 1m 21s
# 100:	learn: 0.6021367	total: 6.54s	remaining: 25.8s
# 1400:	learn: 0.3328973	total: 1m 28s	remaining: 37.9s
# 900:	learn: 0.3641380	total: 57.1s	remaining: 1m 9s
# 1100:	learn: 0.3496446	total: 1m 10s	remaining: 57.8s
# 300:	learn: 0.3968543	total: 17.3s	remaining: 11.5s
# 200:	learn: 0.4374480	total: 11.9s	remaining: 17.7s
# 1400:	learn: 0.3328263	total: 1m 27s	remaining: 37.6s
# 800:	learn: 0.3748829	total: 50.3s	remaining: 1m 15s
# 200:	learn: 0.5108271	total: 13s	remaining: 19.4s
# 1500:	learn: 0.3278817	total: 1m 35s	remaining: 31.6s
# 1000:	learn: 0.3563442	total: 1m 3s	remaining: 1m 3s
# 400:	learn: 0.3734241	total: 23.2s	remaining: 5.72s
# 1200:	learn: 0.3432352	total: 1m 17s	remaining: 51.3s
# 300:	learn: 0.4009991	total: 18.1s	remaining: 11.9s
# 1500:	learn: 0.3278665	total: 1m 34s	remaining: 31.5s
# 900:	learn: 0.3658754	total: 57.1s	remaining: 1m 9s
# 300:	learn: 0.4645370	total: 19.8s	remaining: 13.1s
# 1600:	learn: 0.3233319	total: 1m 41s	remaining: 25.3s
# 1100:	learn: 0.3493826	total: 1m 10s	remaining: 57.3s
# 499:	learn: 0.3570597	total: 29.2s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=1, learning_rate=0.1, rsm=0.8; total time=  29.5s
# 0:	learn: 1.6034620	total: 58.6ms	remaining: 29.3s
# 400:	learn: 0.3772594	total: 24.3s	remaining: 6s
# 1300:	learn: 0.3371077	total: 1m 24s	remaining: 45.1s
# 1600:	learn: 0.3234037	total: 1m 41s	remaining: 25.3s
# 1000:	learn: 0.3578016	total: 1m 4s	remaining: 1m 3s
# 1700:	learn: 0.3188761	total: 1m 48s	remaining: 19.1s
# 400:	learn: 0.4352481	total: 26.9s	remaining: 6.64s
# 1200:	learn: 0.3431726	total: 1m 17s	remaining: 51.3s
# 499:	learn: 0.3605160	total: 30.4s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=1, learning_rate=0.1, rsm=0.8; total time=  30.7s
# 100:	learn: 0.6012668	total: 6.98s	remaining: 27.6s
# 0:	learn: 1.6051251	total: 62.9ms	remaining: 31.4s
# 1400:	learn: 0.3319296	total: 1m 30s	remaining: 38.9s
# 1700:	learn: 0.3191106	total: 1m 48s	remaining: 19s
# 1100:	learn: 0.3510909	total: 1m 10s	remaining: 57.8s
# 1800:	learn: 0.3148107	total: 1m 55s	remaining: 12.7s
# 499:	learn: 0.4147193	total: 33.5s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=3, learning_rate=0.05, rsm=1.0; total time=  33.8s
# 0:	learn: 1.6041740	total: 48.4ms	remaining: 24.1s
# 1300:	learn: 0.3375702	total: 1m 23s	remaining: 45.1s
# 200:	learn: 0.5112965	total: 13.6s	remaining: 20.3s
# 100:	learn: 0.5989444	total: 6.64s	remaining: 26.2s
# 1500:	learn: 0.3271144	total: 1m 37s	remaining: 32.5s
# 1800:	learn: 0.3150476	total: 1m 54s	remaining: 12.7s
# 1900:	learn: 0.3109140	total: 2m 1s	remaining: 6.34s
# 1200:	learn: 0.3448087	total: 1m 17s	remaining: 51.6s
# 100:	learn: 0.6030515	total: 6.62s	remaining: 26.1s
# 1400:	learn: 0.3323691	total: 1m 30s	remaining: 38.7s
# 300:	learn: 0.4656494	total: 20.3s	remaining: 13.4s
# 200:	learn: 0.5104496	total: 13.4s	remaining: 19.9s
# 1600:	learn: 0.3225944	total: 1m 44s	remaining: 26s
# 1900:	learn: 0.3113036	total: 2m 1s	remaining: 6.32s
# 1999:	learn: 0.3072470	total: 2m 8s	remaining: 0us
# 1300:	learn: 0.3393145	total: 1m 23s	remaining: 45.1s
# [CV] END bagging_temperature=0.8, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.05, rsm=1.0; total time= 2.1min
# 200:	learn: 0.5123410	total: 13.3s	remaining: 19.8s
# 0:	learn: 1.6056188	total: 88.7ms	remaining: 44.3s
# 1500:	learn: 0.3275112	total: 1m 37s	remaining: 32.3s
# 400:	learn: 0.4352963	total: 26.9s	remaining: 6.64s
# 300:	learn: 0.4626574	total: 20s	remaining: 13.2s
# 1700:	learn: 0.3184770	total: 1m 51s	remaining: 19.5s
# 1999:	learn: 0.3076320	total: 2m 8s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.05, rsm=1.0; total time= 2.1min
# 0:	learn: 1.5634986	total: 34.2ms	remaining: 1m 8s
# 1400:	learn: 0.3339800	total: 1m 30s	remaining: 38.8s
# 100:	learn: 0.6033268	total: 6.71s	remaining: 26.5s
# 300:	learn: 0.4651246	total: 20s	remaining: 13.2s
# 1600:	learn: 0.3229839	total: 1m 43s	remaining: 25.9s
# 100:	learn: 0.6326618	total: 3.24s	remaining: 1m
# 499:	learn: 0.4141601	total: 33.6s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=3, learning_rate=0.05, rsm=1.0; total time=  33.8s
# 0:	learn: 1.5633914	total: 47.5ms	remaining: 1m 34s
# 400:	learn: 0.4336459	total: 26.9s	remaining: 6.65s
# 1800:	learn: 0.3143716	total: 1m 57s	remaining: 13s
# 200:	learn: 0.5531517	total: 6.47s	remaining: 57.9s
# 100:	learn: 0.6242922	total: 3.32s	remaining: 1m 2s
# 1500:	learn: 0.3291912	total: 1m 37s	remaining: 32.3s
# 400:	learn: 0.4350596	total: 26.5s	remaining: 6.55s
# 200:	learn: 0.5150246	total: 13.4s	remaining: 19.9s
# 1700:	learn: 0.3186578	total: 1m 50s	remaining: 19.4s
# 300:	learn: 0.5105786	total: 9.58s	remaining: 54.1s
# 499:	learn: 0.4133897	total: 33.2s	remaining: 0us
# 200:	learn: 0.5509888	total: 6.67s	remaining: 59.7s
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=3, learning_rate=0.05, rsm=1.0; total time=  33.5s
# 0:	learn: 1.5648451	total: 26ms	remaining: 51.9s
# 1900:	learn: 0.3104409	total: 2m 4s	remaining: 6.47s
# 400:	learn: 0.4821038	total: 12.7s	remaining: 50.8s
# 300:	learn: 0.5084099	total: 9.74s	remaining: 55s
# 1600:	learn: 0.3245921	total: 1m 43s	remaining: 25.8s
# 100:	learn: 0.6312181	total: 3.04s	remaining: 57.1s
# 499:	learn: 0.4135824	total: 32.7s	remaining: 0us
# 300:	learn: 0.4670322	total: 19.5s	remaining: 12.9s
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=3, learning_rate=0.05, rsm=1.0; total time=  33.0s
# 0:	learn: 1.5641785	total: 22.8ms	remaining: 45.5s
# 1800:	learn: 0.3145923	total: 1m 56s	remaining: 12.9s
# 500:	learn: 0.4624433	total: 15.8s	remaining: 47.3s
# 400:	learn: 0.4812516	total: 12.7s	remaining: 50.7s
# 200:	learn: 0.5514984	total: 6.04s	remaining: 54.1s
# 1999:	learn: 0.3068117	total: 2m 10s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.05, rsm=1.0; total time= 2.2min
# 100:	learn: 0.6311277	total: 3.08s	remaining: 57.9s
# 0:	learn: 1.5655831	total: 22.7ms	remaining: 45.5s
# 600:	learn: 0.4480596	total: 19.3s	remaining: 45s
# 500:	learn: 0.4613472	total: 16.2s	remaining: 48.5s
# 300:	learn: 0.5098570	total: 9.53s	remaining: 53.8s
# 1700:	learn: 0.3202890	total: 1m 49s	remaining: 19.3s
# 400:	learn: 0.4390558	total: 26.1s	remaining: 6.45s
# 100:	learn: 0.6337172	total: 3.35s	remaining: 1m 2s
# 200:	learn: 0.5511630	total: 6.55s	remaining: 58.6s
# 1900:	learn: 0.3106902	total: 2m 3s	remaining: 6.42s
# 700:	learn: 0.4364222	total: 22.6s	remaining: 41.9s
# 600:	learn: 0.4474822	total: 19.4s	remaining: 45.3s
# 400:	learn: 0.4810488	total: 12.7s	remaining: 50.8s
# 300:	learn: 0.5110111	total: 9.81s	remaining: 55.4s
# 200:	learn: 0.5537811	total: 6.62s	remaining: 59.3s
# 800:	learn: 0.4272218	total: 25.5s	remaining: 38.1s
# 700:	learn: 0.4355178	total: 22.2s	remaining: 41.2s
# 500:	learn: 0.4615561	total: 15.5s	remaining: 46.5s
# 1800:	learn: 0.3163228	total: 1m 56s	remaining: 12.8s
# 499:	learn: 0.4173853	total: 32s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=500, l2_leaf_reg=3, learning_rate=0.05, rsm=1.0; total time=  32.2s
# 0:	learn: 1.6485315	total: 64.5ms	remaining: 2m 8s
# 300:	learn: 0.5132426	total: 9.41s	remaining: 53.1s
# 400:	learn: 0.4816447	total: 12.6s	remaining: 50.3s
# 1999:	learn: 0.3070660	total: 2m 9s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.05, rsm=1.0; total time= 2.2min
# 0:	learn: 1.6476533	total: 72.8ms	remaining: 2m 25s
# 900:	learn: 0.4190940	total: 28.6s	remaining: 34.9s
# 800:	learn: 0.4265951	total: 25.4s	remaining: 38s
# 600:	learn: 0.4469024	total: 18.6s	remaining: 43.4s
# 400:	learn: 0.4848776	total: 12.6s	remaining: 50s
# 500:	learn: 0.4629697	total: 15.8s	remaining: 47.2s
# 1000:	learn: 0.4118855	total: 31.5s	remaining: 31.5s
# 1900:	learn: 0.3124995	total: 2m 1s	remaining: 6.35s
# 900:	learn: 0.4192879	total: 28.4s	remaining: 34.6s
# 700:	learn: 0.4355911	total: 21.7s	remaining: 40.3s
# 100:	learn: 0.9997667	total: 6.12s	remaining: 1m 55s
# 500:	learn: 0.4659670	total: 15.6s	remaining: 46.5s
# 600:	learn: 0.4481114	total: 18.8s	remaining: 43.8s
# 100:	learn: 0.9974854	total: 5.97s	remaining: 1m 52s
# 1100:	learn: 0.4061607	total: 34.5s	remaining: 28.1s
# 1000:	learn: 0.4122976	total: 31.2s	remaining: 31.1s
# 800:	learn: 0.4261639	total: 24.5s	remaining: 36.7s
# 600:	learn: 0.4503544	total: 18.4s	remaining: 42.7s
# 700:	learn: 0.4365069	total: 21.6s	remaining: 40s
# 1200:	learn: 0.4009843	total: 37.3s	remaining: 24.8s
# 1999:	learn: 0.3089289	total: 2m 7s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=10, iterations=2000, l2_leaf_reg=1, learning_rate=0.05, rsm=1.0; total time= 2.1min
# 1100:	learn: 0.4056922	total: 34.1s	remaining: 27.8s
# 900:	learn: 0.4179831	total: 27.4s	remaining: 33.4s
# 0:	learn: 1.6495309	total: 63.8ms	remaining: 2m 7s
# 200:	learn: 0.7828377	total: 11.8s	remaining: 1m 45s
# 700:	learn: 0.4395525	total: 21.2s	remaining: 39.3s
# 800:	learn: 0.4267284	total: 24.6s	remaining: 36.8s
# 200:	learn: 0.7846912	total: 11.6s	remaining: 1m 43s
# 1300:	learn: 0.3963233	total: 40.4s	remaining: 21.7s
# 1200:	learn: 0.4001616	total: 36.8s	remaining: 24.5s
# 1000:	learn: 0.4111312	total: 30.2s	remaining: 30.1s
# 900:	learn: 0.4184301	total: 27.1s	remaining: 33.1s
# 800:	learn: 0.4304441	total: 24.8s	remaining: 37.1s
# 1400:	learn: 0.3920187	total: 42.8s	remaining: 18.3s
# 1300:	learn: 0.3956631	total: 39.4s	remaining: 21.1s
# 1100:	learn: 0.4054209	total: 32.6s	remaining: 26.7s
# 300:	learn: 0.6936410	total: 16.8s	remaining: 1m 34s
# 1000:	learn: 0.4115416	total: 29.7s	remaining: 29.6s
# 100:	learn: 0.9967001	total: 6.27s	remaining: 1m 57s
# 1500:	learn: 0.3881492	total: 45.5s	remaining: 15.1s
# 300:	learn: 0.6932053	total: 17.8s	remaining: 1m 40s
# 900:	learn: 0.4226077	total: 28.2s	remaining: 34.4s
# 1400:	learn: 0.3911442	total: 42s	remaining: 18s
# 1200:	learn: 0.3999331	total: 35.4s	remaining: 23.5s
# 1100:	learn: 0.4056911	total: 32.4s	remaining: 26.5s
# 1600:	learn: 0.3845139	total: 48.3s	remaining: 12s
# 1000:	learn: 0.4151126	total: 31s	remaining: 30.9s
# 1500:	learn: 0.3874032	total: 44.8s	remaining: 14.9s
# 1300:	learn: 0.3956715	total: 38.1s	remaining: 20.5s
# 400:	learn: 0.6408182	total: 22.1s	remaining: 1m 28s
# 1200:	learn: 0.4004733	total: 35.3s	remaining: 23.5s
# 200:	learn: 0.7811237	total: 11.9s	remaining: 1m 46s
# 400:	learn: 0.6420988	total: 23.1s	remaining: 1m 32s
# 1700:	learn: 0.3811419	total: 51.2s	remaining: 8.99s
# 1100:	learn: 0.4090877	total: 33.8s	remaining: 27.6s
# ...
# 300:	learn: 0.5231682	total: 12.1s	remaining: 28s
# 500:	learn: 0.5270128	total: 15.9s	remaining: 15.8s
# 600:	learn: 0.5089417	total: 19.2s	remaining: 12.7s
# 700:	learn: 0.4928353	total: 21.8s	remaining: 9.31s
# 600:	learn: 0.5067065	total: 19.1s	remaining: 12.7s
# 999:	learn: 0.4594957	total: 30.5s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, rsm=1.0; total time=  30.7s
# 100:	learn: 0.6642376	total: 3.94s	remaining: 35.1s
# 0:	learn: 1.6069912	total: 33.2ms	remaining: 33.2s
# 100:	learn: 0.6597157	total: 3.76s	remaining: 33.5s
# 600:	learn: 0.5082518	total: 18.8s	remaining: 12.5s
# 400:	learn: 0.4916610	total: 15.6s	remaining: 23.4s
# 700:	learn: 0.4921022	total: 22.1s	remaining: 9.43s
# 800:	learn: 0.4807344	total: 24.9s	remaining: 6.19s
# 700:	learn: 0.4923596	total: 22.3s	remaining: 9.53s
# 700:	learn: 0.4926157	total: 22s	remaining: 9.37s
# 200:	learn: 0.5690068	total: 8.11s	remaining: 32.2s
# 100:	learn: 0.6641435	total: 4.25s	remaining: 37.8s
# 200:	learn: 0.5664312	total: 7.9s	remaining: 31.4s
# 800:	learn: 0.4791485	total: 25.5s	remaining: 6.33s
# 500:	learn: 0.4680445	total: 20s	remaining: 19.9s
# 900:	learn: 0.4698939	total: 27.9s	remaining: 3.06s
# 800:	learn: 0.4803154	total: 25.2s	remaining: 6.27s
# 800:	learn: 0.4808626	total: 24.9s	remaining: 6.18s
# 300:	learn: 0.5208581	total: 11.6s	remaining: 27s
# 200:	learn: 0.5707768	total: 7.69s	remaining: 30.6s
# 300:	learn: 0.5188345	total: 11.6s	remaining: 27.1s
# 900:	learn: 0.4688814	total: 28.3s	remaining: 3.11s
# 999:	learn: 0.4605717	total: 30.5s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, rsm=1.0; total time=  30.8s
# 0:	learn: 1.6084158	total: 52.9ms	remaining: 52.9s
# 900:	learn: 0.4691238	total: 28s	remaining: 3.08s
# 600:	learn: 0.4503089	total: 23.6s	remaining: 15.7s
# 900:	learn: 0.4694597	total: 27.6s	remaining: 3.03s
# 999:	learn: 0.4596310	total: 31s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, rsm=1.0; total time=  31.3s
# 0:	learn: 1.5560857	total: 25.3ms	remaining: 12.6s
# 400:	learn: 0.4890245	total: 15.1s	remaining: 22.6s
# 300:	learn: 0.5229568	total: 11.2s	remaining: 26.1s
# 400:	learn: 0.4886637	total: 15s	remaining: 22.4s
# 100:	learn: 0.6604798	total: 3.33s	remaining: 29.6s
# 999:	learn: 0.4594666	total: 31.3s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, rsm=1.0; total time=  31.5s
# 999:	learn: 0.4612396	total: 30.1s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.05, rsm=1.0; total time=  30.4s
# 0:	learn: 1.5551314	total: 41.6ms	remaining: 20.8s
# 0:	learn: 1.5566039	total: 34.9ms	remaining: 17.4s
# 700:	learn: 0.4361649	total: 27.5s	remaining: 11.7s
# 100:	learn: 0.5599011	total: 3.04s	remaining: 12s
# 500:	learn: 0.4659711	total: 18.1s	remaining: 18s
# 200:	learn: 0.5686103	total: 6.47s	remaining: 25.7s
# 100:	learn: 0.5601757	total: 3.09s	remaining: 12.2s
# 100:	learn: 0.5580750	total: 3.12s	remaining: 12.3s
# 500:	learn: 0.4663936	total: 19.6s	remaining: 19.6s
# 400:	learn: 0.4905902	total: 15.7s	remaining: 23.5s
# 800:	learn: 0.4251073	total: 31.7s	remaining: 7.87s
# 200:	learn: 0.4838581	total: 6.49s	remaining: 9.65s
# 600:	learn: 0.4481489	total: 21.6s	remaining: 14.4s
# 300:	learn: 0.5206257	total: 9.96s	remaining: 23.1s
# 200:	learn: 0.4827924	total: 6.69s	remaining: 9.96s
# 200:	learn: 0.4789576	total: 6.63s	remaining: 9.86s
# 500:	learn: 0.4674693	total: 19.4s	remaining: 19.3s
# 600:	learn: 0.4485366	total: 23.4s	remaining: 15.5s
# 900:	learn: 0.4155040	total: 35.3s	remaining: 3.88s
# 300:	learn: 0.4439446	total: 10.3s	remaining: 6.83s
# 700:	learn: 0.4343625	total: 25.6s	remaining: 10.9s
# 400:	learn: 0.4902570	total: 13.8s	remaining: 20.7s
# 300:	learn: 0.4423401	total: 10.5s	remaining: 6.93s
# 300:	learn: 0.4412231	total: 10.5s	remaining: 6.91s
# 600:	learn: 0.4485328	total: 23.2s	remaining: 15.4s
# 700:	learn: 0.4350359	total: 27.3s	remaining: 11.6s
# 999:	learn: 0.4076887	total: 39.1s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.05, rsm=0.8; total time=  39.4s
# 400:	learn: 0.4192914	total: 13.8s	remaining: 3.4s
# 0:	learn: 1.5559872	total: 41ms	remaining: 20.5s
# 800:	learn: 0.4231745	total: 29.2s	remaining: 7.25s
# 400:	learn: 0.4172734	total: 13.9s	remaining: 3.43s
# 400:	learn: 0.4185707	total: 14.1s	remaining: 3.47s
# 500:	learn: 0.4676791	total: 17.8s	remaining: 17.7s
# 700:	learn: 0.4346068	total: 26.7s	remaining: 11.4s
# 800:	learn: 0.4240197	total: 30.8s	remaining: 7.66s
# 100:	learn: 0.5587638	total: 3.54s	remaining: 14s
# 499:	learn: 0.4027100	total: 17.3s	remaining: 0us
# [CV] END bagging_temperature=1, depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.1, rsm=1.0; total time=  17.5s
# 0:	learn: 1.5574171	total: 26ms	remaining: 13s
# 900:	learn: 0.4138865	total: 32.8s	remaining: 3.6s
# 499:	learn: 0.4013675	total: 17.4s	remaining: 0us
# [CV] END bagging_temperature=1, depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.1, rsm=1.0; total time=  17.6s
# 499:	learn: 0.4017654	total: 17.6s	remaining: 0us
# [CV] END bagging_temperature=1, depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.1, rsm=1.0; total time=  17.8s
# 0:	learn: 1.5540827	total: 30.7ms	remaining: 15.3s
# 0:	learn: 1.5542941	total: 38ms	remaining: 19s
# 600:	learn: 0.4502666	total: 21.5s	remaining: 14.3s
# 800:	learn: 0.4237472	total: 30.4s	remaining: 7.56s
# 900:	learn: 0.4146910	total: 34.6s	remaining: 3.8s
# 200:	learn: 0.4809809	total: 6.88s	remaining: 10.2s
# 100:	learn: 0.5605940	total: 3.39s	remaining: 13.4s
# 999:	learn: 0.4061796	total: 36.2s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.05, rsm=0.8; total time=  36.4s
# 0:	learn: 1.5558045	total: 30ms	remaining: 14.9s
# 100:	learn: 0.5683307	total: 3.38s	remaining: 13.4s
# 100:	learn: 0.5636827	total: 3.39s	remaining: 13.4s
# 900:	learn: 0.4146400	total: 33.8s	remaining: 3.72s
# 700:	learn: 0.4367705	total: 25.9s	remaining: 11s
# 999:	learn: 0.4065975	total: 38.5s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.05, rsm=0.8; total time=  38.9s
# 0:	learn: 1.5550994	total: 65.9ms	remaining: 32.9s
# 300:	learn: 0.4423571	total: 10.8s	remaining: 7.15s
# 200:	learn: 0.4859990	total: 7.12s	remaining: 10.6s
# 100:	learn: 0.5662042	total: 3.83s	remaining: 15.1s
# 200:	learn: 0.4847791	total: 7.25s	remaining: 10.8s
# 200:	learn: 0.4836444	total: 7.33s	remaining: 10.9s
# 999:	learn: 0.4069231	total: 37.7s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.05, rsm=0.8; total time=  38.1s
# 0:	learn: 1.5565255	total: 35.2ms	remaining: 17.6s
# 800:	learn: 0.4256885	total: 29.7s	remaining: 7.39s
# 100:	learn: 0.5653087	total: 3.86s	remaining: 15.2s
# 400:	learn: 0.4181706	total: 14.5s	remaining: 3.59s
# 300:	learn: 0.4451494	total: 10.9s	remaining: 7.24s
# 200:	learn: 0.4825413	total: 7.64s	remaining: 11.4s
# 300:	learn: 0.4434586	total: 10.9s	remaining: 7.21s
# 300:	learn: 0.4439251	total: 11s	remaining: 7.28s
# 100:	learn: 0.5677667	total: 3.67s	remaining: 14.5s
# 900:	learn: 0.4165044	total: 33.4s	remaining: 3.67s
# 200:	learn: 0.4848246	total: 7.42s	remaining: 11s
# 499:	learn: 0.4009842	total: 18.1s	remaining: 0us
# [CV] END bagging_temperature=1, depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.1, rsm=1.0; total time=  18.3s
# 400:	learn: 0.4212538	total: 14.5s	remaining: 3.58s
# 0:	learn: 1.6498456	total: 29ms	remaining: 29s
# 300:	learn: 0.4423156	total: 11.3s	remaining: 7.49s
# 400:	learn: 0.4191891	total: 14.7s	remaining: 3.63s
# 400:	learn: 0.4199841	total: 15.1s	remaining: 3.72s
# 200:	learn: 0.4858943	total: 7.42s	remaining: 11s
# 999:	learn: 0.4091856	total: 37.1s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=1000, l2_leaf_reg=10, learning_rate=0.05, rsm=0.8; total time=  37.4s
# 0:	learn: 1.6490441	total: 23ms	remaining: 23s
# 100:	learn: 1.0886616	total: 3.02s	remaining: 26.9s
# 300:	learn: 0.4443789	total: 11.1s	remaining: 7.35s
# 499:	learn: 0.4045126	total: 18.2s	remaining: 0us
# [CV] END bagging_temperature=1, depth=8, iterations=500, l2_leaf_reg=3, learning_rate=0.1, rsm=1.0; total time=  18.4s
# 0:	learn: 1.6509273	total: 29.6ms	remaining: 29.5s
# 400:	learn: 0.4191267	total: 15s	remaining: 3.7s
# 499:	learn: 0.4024529	total: 18.4s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.1, rsm=0.8; total time=  18.7s
# 0:	learn: 1.6497739	total: 25ms	remaining: 25s
# 499:	learn: 0.4034057	total: 18.8s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.1, rsm=0.8; total time=  18.9s
# 0:	learn: 1.6511968	total: 23ms	remaining: 23s
# 200:	learn: 0.9063899	total: 5.89s	remaining: 23.4s
# 300:	learn: 0.4468206	total: 11s	remaining: 7.27s
# 100:	learn: 1.0873215	total: 3.27s	remaining: 29.1s
# 100:	learn: 1.0871478	total: 2.78s	remaining: 24.7s
# 400:	learn: 0.4189535	total: 14.7s	remaining: 3.63s
# 100:	learn: 1.0887191	total: 2.84s	remaining: 25.3s
# 499:	learn: 0.4027493	total: 18.5s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.1, rsm=0.8; total time=  18.7s
# 0:	learn: 1.6485934	total: 52.6ms	remaining: 26.3s
# 100:	learn: 1.0905380	total: 3s	remaining: 26.7s
# 300:	learn: 0.8244065	total: 8.87s	remaining: 20.6s
# 200:	learn: 0.9041511	total: 6.12s	remaining: 24.3s
# 200:	learn: 0.9036192	total: 5.68s	remaining: 22.6s
# 400:	learn: 0.4208973	total: 14.6s	remaining: 3.61s
# 499:	learn: 0.4027723	total: 18.3s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.1, rsm=0.8; total time=  18.5s
# 0:	learn: 1.6477154	total: 52.5ms	remaining: 26.2s
# 200:	learn: 0.9063669	total: 5.71s	remaining: 22.7s
# 300:	learn: 0.8225050	total: 9.04s	remaining: 21s
# 200:	learn: 0.9060062	total: 6.02s	remaining: 23.9s
# 400:	learn: 0.7688690	total: 11.9s	remaining: 17.7s
# 300:	learn: 0.8226537	total: 8.66s	remaining: 20.1s
# 499:	learn: 0.4042614	total: 18.3s	remaining: 0us
# [CV] END bagging_temperature=0.8, depth=8, iterations=500, l2_leaf_reg=1, learning_rate=0.1, rsm=0.8; total time=  18.6s
# 0:	learn: 1.6495932	total: 121ms	remaining: 1m
# 300:	learn: 0.8240211	total: 8.83s	remaining: 20.5s
# 100:	learn: 1.0027974	total: 6.13s	remaining: 24.2s
# 400:	learn: 0.7686462	total: 12s	remaining: 17.9s
# 500:	learn: 0.7308400	total: 15s	remaining: 15s
# 300:	learn: 0.8235089	total: 9.36s	remaining: 21.7s
# 400:	learn: 0.7701086	total: 11.8s	remaining: 17.6s
# 100:	learn: 1.0000191	total: 6.26s	remaining: 24.7s
# 400:	learn: 0.7722745	total: 11.8s	remaining: 17.6s
# 500:	learn: 0.7316597	total: 15.2s	remaining: 15.2s
# 600:	learn: 0.7020569	total: 18.2s	remaining: 12.1s
# 400:	learn: 0.7700705	total: 12.5s	remaining: 18.7s
# 500:	learn: 0.7310356	total: 15s	remaining: 14.9s
# 100:	learn: 1.0005316	total: 6.21s	remaining: 24.5s
# 500:	learn: 0.7328530	total: 14.8s	remaining: 14.7s
# 200:	learn: 0.7860886	total: 12.2s	remaining: 18.1s
# 600:	learn: 0.7018217	total: 18.2s	remaining: 12.1s
# 700:	learn: 0.6799312	total: 21.2s	remaining: 9.03s
# 500:	learn: 0.7320504	total: 15.5s	remaining: 15.4s
# 600:	learn: 0.7023556	total: 17.9s	remaining: 11.9s
# 200:	learn: 0.7853493	total: 12.3s	remaining: 18.3s
# 600:	learn: 0.7035276	total: 17.7s	remaining: 11.8s
# 700:	learn: 0.6795047	total: 21.1s	remaining: 8.98s
# 800:	learn: 0.6623374	total: 24s	remaining: 5.97s
# 600:	learn: 0.7021580	total: 18.4s	remaining: 12.2s
# 700:	learn: 0.6790760	total: 21s	remaining: 8.98s
# 200:	learn: 0.7849465	total: 11.7s	remaining: 17.4s
# 700:	learn: 0.6822028	total: 20.6s	remaining: 8.77s
# 300:	learn: 0.6944009	total: 17.8s	remaining: 11.7s
# 800:	learn: 0.6623455	total: 23.9s	remaining: 5.94s
# 900:	learn: 0.6463718	total: 27s	remaining: 2.97s
# 700:	learn: 0.6790895	total: 21.3s	remaining: 9.1s
# 800:	learn: 0.6611999	total: 24.4s	remaining: 6.05s
# 300:	learn: 0.6962113	total: 18.5s	remaining: 12.3s
# 800:	learn: 0.6637530	total: 24.1s	remaining: 6s
# 900:	learn: 0.6462627	total: 27.2s	remaining: 2.99s
# 999:	learn: 0.6328535	total: 30.3s	remaining: 0us
# [CV] END bagging_temperature=1, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time=  30.6s
# 800:	learn: 0.6610473	total: 24.6s	remaining: 6.12s
# 0:	learn: 1.6484367	total: 58.4ms	remaining: 29.2s
# 900:	learn: 0.6445946	total: 27.5s	remaining: 3.02s
# 300:	learn: 0.6935880	total: 18s	remaining: 11.9s
# 900:	learn: 0.6478446	total: 27.2s	remaining: 2.98s
# 400:	learn: 0.6439965	total: 24.3s	remaining: 6s
# 999:	learn: 0.6329677	total: 30.3s	remaining: 0us
# [CV] END bagging_temperature=1, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time=  30.5s
# 0:	learn: 1.6498654	total: 56.9ms	remaining: 28.4s
# 900:	learn: 0.6457963	total: 27.9s	remaining: 3.07s
# 999:	learn: 0.6311174	total: 30.6s	remaining: 0us
# [CV] END bagging_temperature=1, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time=  30.9s
# 400:	learn: 0.6442728	total: 24.5s	remaining: 6.04s
# 999:	learn: 0.6346422	total: 30.2s	remaining: 0us
# [CV] END bagging_temperature=1, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time=  30.5s
# 999:	learn: 0.6334110	total: 30.6s	remaining: 0us
# 100:	learn: 1.0024050	total: 5.84s	remaining: 23.1s
# [CV] END bagging_temperature=1, depth=6, iterations=1000, l2_leaf_reg=3, learning_rate=0.01, rsm=0.8; total time=  30.9s
# 400:	learn: 0.6406416	total: 23.3s	remaining: 5.75s
# 499:	learn: 0.6090532	total: 29.4s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=500, l2_leaf_reg=10, learning_rate=0.01, rsm=1.0; total time=  29.6s
# 100:	learn: 1.0038212	total: 4.8s	remaining: 18.9s
# 499:	learn: 0.6092273	total: 28.5s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=500, l2_leaf_reg=10, learning_rate=0.01, rsm=1.0; total time=  28.7s
# 200:	learn: 0.7889851	total: 9.11s	remaining: 13.5s
# 499:	learn: 0.6065003	total: 26.4s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=500, l2_leaf_reg=10, learning_rate=0.01, rsm=1.0; total time=  26.6s
# 200:	learn: 0.7866355	total: 7.25s	remaining: 10.8s
# 300:	learn: 0.6963046	total: 10.9s	remaining: 7.2s
# 300:	learn: 0.6952105	total: 8.95s	remaining: 5.92s
# 400:	learn: 0.6444955	total: 12.6s	remaining: 3.1s
# 400:	learn: 0.6446520	total: 10.6s	remaining: 2.63s
# 499:	learn: 0.6092877	total: 14.2s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=500, l2_leaf_reg=10, learning_rate=0.01, rsm=1.0; total time=  14.4s
# 499:	learn: 0.6108010	total: 12.1s	remaining: 0us
# [CV] END bagging_temperature=1, depth=10, iterations=500, l2_leaf_reg=10, learning_rate=0.01, rsm=1.0; total time=  12.3s
# 0:	learn: 1.5491102	total: 18.2ms	remaining: 36.4s
# 100:	learn: 0.5147292	total: 1.02s	remaining: 19.1s
# 200:	learn: 0.4394991	total: 2.16s	remaining: 19.3s
# 300:	learn: 0.4034505	total: 3.33s	remaining: 18.8s
# 400:	learn: 0.3815688	total: 4.36s	remaining: 17.4s
# 500:	learn: 0.3665939	total: 5.39s	remaining: 16.1s
# 600:	learn: 0.3544744	total: 6.4s	remaining: 14.9s
# 700:	learn: 0.3446927	total: 7.38s	remaining: 13.7s
# 800:	learn: 0.3363628	total: 8.39s	remaining: 12.6s
# 900:	learn: 0.3294495	total: 9.48s	remaining: 11.6s
# 1000:	learn: 0.3232432	total: 10.5s	remaining: 10.5s
# 1100:	learn: 0.3172403	total: 11.5s	remaining: 9.36s
# 1200:	learn: 0.3117769	total: 12.6s	remaining: 8.39s
# 1300:	learn: 0.3070123	total: 13.6s	remaining: 7.33s
# 1400:	learn: 0.3026294	total: 14.9s	remaining: 6.36s
# 1500:	learn: 0.2986293	total: 15.9s	remaining: 5.28s
# 1600:	learn: 0.2950445	total: 16.9s	remaining: 4.2s
# 1700:	learn: 0.2914061	total: 17.9s	remaining: 3.14s
# 1800:	learn: 0.2880375	total: 18.9s	remaining: 2.09s
# 1900:	learn: 0.2848026	total: 19.9s	remaining: 1.04s
# 1999:	learn: 0.2816746	total: 20.9s	remaining: 0us
# Best Parameters: {'rsm': 0.8, 'learning_rate': 0.1, 'l2_leaf_reg': 5, 'iterations': 2000, 'depth': 10, 'bagging_temperature': 1}
# Best Score: 0.1273861060331006

# %%
# Step 5: Train the final model on the full training set with eval_set
best_params = random_search.best_params_

final_model = CatBoostRegressor(
    **best_params,
    loss_function='RMSE',
    random_seed=42,
    verbose=100,
    use_best_model=True  # Ensure best iteration is selected
)

final_model.fit(
    X_train_split,
    y_train_split,
    eval_set=(X_val_split, y_val_split),
    early_stopping_rounds=50  # Stops if no improvement for 50 iterations
)
# Out:
# 0:	learn: 1.5520818	test: 1.5506976	best: 1.5506976 (0)	total: 22.8ms	remaining: 45.5s
# 100:	learn: 0.5164090	test: 0.5157534	best: 0.5157534 (100)	total: 2.22s	remaining: 41.8s
# 200:	learn: 0.4424089	test: 0.4437167	best: 0.4437167 (200)	total: 4.37s	remaining: 39.1s
# 300:	learn: 0.4088735	test: 0.4117168	best: 0.4117168 (300)	total: 6.54s	remaining: 36.9s
# 400:	learn: 0.3886461	test: 0.3934111	best: 0.3934111 (400)	total: 8.71s	remaining: 34.7s
# 500:	learn: 0.3745411	test: 0.3810397	best: 0.3810397 (500)	total: 11s	remaining: 32.8s
# 600:	learn: 0.3639318	test: 0.3721866	best: 0.3721866 (600)	total: 13.2s	remaining: 30.7s
# 700:	learn: 0.3557594	test: 0.3656754	best: 0.3656754 (700)	total: 15.5s	remaining: 28.7s
# 800:	learn: 0.3492878	test: 0.3608026	best: 0.3608026 (800)	total: 17.7s	remaining: 26.4s
# 900:	learn: 0.3436169	test: 0.3565898	best: 0.3565898 (900)	total: 19.8s	remaining: 24.2s
# 1000:	learn: 0.3386148	test: 0.3531363	best: 0.3531363 (1000)	total: 22.2s	remaining: 22.2s
# 1100:	learn: 0.3344606	test: 0.3504340	best: 0.3504340 (1100)	total: 24.9s	remaining: 20.3s
# 1200:	learn: 0.3305514	test: 0.3479986	best: 0.3479986 (1200)	total: 27.2s	remaining: 18.1s
# 1300:	learn: 0.3270321	test: 0.3459174	best: 0.3459174 (1300)	total: 29.5s	remaining: 15.9s
# 1400:	learn: 0.3237179	test: 0.3442098	best: 0.3442098 (1400)	total: 32.3s	remaining: 13.8s
# 1500:	learn: 0.3208168	test: 0.3427598	best: 0.3427598 (1500)	total: 35s	remaining: 11.6s
# 1600:	learn: 0.3181456	test: 0.3416073	best: 0.3416073 (1600)	total: 37.4s	remaining: 9.33s
# 1700:	learn: 0.3155430	test: 0.3405239	best: 0.3405239 (1700)	total: 39.6s	remaining: 6.96s
# 1800:	learn: 0.3131724	test: 0.3394170	best: 0.3394170 (1800)	total: 42.1s	remaining: 4.65s
# 1900:	learn: 0.3108495	test: 0.3384928	best: 0.3384928 (1900)	total: 44.4s	remaining: 2.31s
# 1999:	learn: 0.3085995	test: 0.3376404	best: 0.3376404 (1999)	total: 46.5s	remaining: 0us
#
# bestTest = 0.337640376
# bestIteration = 1999

# %%
# Step 6: Make predictions on the test set
y_predictions = final_model.predict(X_test)

# %%
print(y_predictions)
# Out:
# [0.41039275 1.63160619 2.02659416 ... 5.23482533 4.676473   3.64370671]

# %%
pd.DataFrame(y_predictions, columns=["log_bike_count"]).reset_index().rename(
    columns={"index": "Id"}
).to_csv("/Users/louisleibovici/Documents/VS_Code/Bike_counters DSB Project/bike_counters/predictions_CatBoost_reg.csv", index=False)
