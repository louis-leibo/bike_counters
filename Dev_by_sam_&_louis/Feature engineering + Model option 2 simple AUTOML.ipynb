# %%
import pandas as pd
import numpy as np
from tpot import TPOTRegressor
from skrub import TableVectorizer
import xgboost as xgb
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
# Import the files
df_train = pd.read_parquet("/Users/louisleibovici/Documents/VS_Code/Bike_counters DSB Project/bike_counters/data/train.parquet")
df_test = pd.read_parquet("/Users/louisleibovici/Documents/VS_Code/Bike_counters DSB Project/bike_counters/data/final_test.parquet")

# %%
# Extract the date feature on different time scales :

def _encode_dates(X):
    X = X.copy()  # modify a copy of X
    # Encode the date information from the DateOfDeparture columns
    X["year"] = X["date"].dt.year
    X["month"] = X["date"].dt.month
    X["day"] = X["date"].dt.day
    X["weekday"] = X["date"].dt.weekday
    X["hour"] = X["date"].dt.hour

    # creation of a binary varible depicting if day in weekend
    X["is_weekend"] = np.where(X["weekday"] + 1 > 5, 1, 0)

    # Finally we can drop the original columns from the dataframe
    return X.drop(columns=["date"])

df_train = _encode_dates(df_train)
df_test = _encode_dates(df_test)

# %%
df_train.head()
# Out:
#                 counter_id              counter_name    site_id  \
# 48321  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48324  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48327  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48330  100007049-102007049  28 boulevard Diderot E-O  100007049
# 48333  100007049-102007049  28 boulevard Diderot E-O  100007049
#
#                   site_name  bike_count counter_installation_date  \
# 48321  28 boulevard Diderot         0.0                2013-01-18
# 48324  28 boulevard Diderot         1.0                2013-01-18
# 48327  28 boulevard Diderot         0.0                2013-01-18
# 48330  28 boulevard Diderot         4.0                2013-01-18
# 48333  28 boulevard Diderot         9.0                2013-01-18
#
#               coordinates counter_technical_id   latitude  longitude  \
# 48321  48.846028,2.375429          Y2H15027244  48.846028   2.375429
# 48324  48.846028,2.375429          Y2H15027244  48.846028   2.375429
# 48327  48.846028,2.375429          Y2H15027244  48.846028   2.375429
# 48330  48.846028,2.375429          Y2H15027244  48.846028   2.375429
# 48333  48.846028,2.375429          Y2H15027244  48.846028   2.375429
#
#        log_bike_count  year  month  day  weekday  hour  is_weekend
# 48321        0.000000  2020      9    1        1     2           0
# 48324        0.693147  2020      9    1        1     3           0
# 48327        0.000000  2020      9    1        1     4           0
# 48330        1.609438  2020      9    1        1    15           0
# 48333        2.302585  2020      9    1        1    18           0

# %%
df_test.head()
# Out:
#             counter_id              counter_name    site_id  \
# 0  100007049-102007049  28 boulevard Diderot E-O  100007049
# 1  100007049-102007049  28 boulevard Diderot E-O  100007049
# 2  100007049-102007049  28 boulevard Diderot E-O  100007049
# 3  100007049-102007049  28 boulevard Diderot E-O  100007049
# 4  100007049-102007049  28 boulevard Diderot E-O  100007049
#
#               site_name counter_installation_date         coordinates  \
# 0  28 boulevard Diderot                2013-01-18  48.846028,2.375429
# 1  28 boulevard Diderot                2013-01-18  48.846028,2.375429
# 2  28 boulevard Diderot                2013-01-18  48.846028,2.375429
# 3  28 boulevard Diderot                2013-01-18  48.846028,2.375429
# 4  28 boulevard Diderot                2013-01-18  48.846028,2.375429
#
#   counter_technical_id   latitude  longitude  year  month  day  weekday  hour  \
# 0          Y2H15027244  48.846028   2.375429  2021      9   10        4     1
# 1          Y2H15027244  48.846028   2.375429  2021      9   10        4    13
# 2          Y2H15027244  48.846028   2.375429  2021      9   10        4    17
# 3          Y2H15027244  48.846028   2.375429  2021      9   10        4    19
# 4          Y2H15027244  48.846028   2.375429  2021      9   10        4    22
#
#    is_weekend
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# std        0.462030

# %%
X_train = df_train.drop(columns=["bike_count", "log_bike_count"])
y_train = df_train["log_bike_count"]

X_test = df_test.copy()

# %%
non_numeric_columns = X_train.select_dtypes(include=["object", "category"]).columns
print("Non-numeric columns:", non_numeric_columns)

# we convert them to numeric using label encoding :
label_encoder = LabelEncoder()
for col in non_numeric_columns:
    X_train[col] = label_encoder.fit_transform(X_train[col])
    X_test[col] = label_encoder.transform(X_test[col])
# Out:
# Non-numeric columns: Index(['counter_id', 'counter_name', 'site_name', 'coordinates',
#        'counter_technical_id'],
#       dtype='object')

# %%
# and for the counter_installation_date : to convert it to normal date :
for df in [X_train, X_test]:
    df["installation_year"] = df["counter_installation_date"].dt.year
    # df["installation_month"] = df["counter_installation_date"].dt.month
    # df["installation_day"] = df["counter_installation_date"].dt.day
    # df["days_since_installation"] = (pd.Timestamp.now() - df["counter_installation_date"]).dt.days

# Drop the original 'counter_installation_date' column
X_train = X_train.drop(columns=["counter_installation_date"])
X_test = X_test.drop(columns=["counter_installation_date"])

# %%
X_train.head()
# Out:
#        counter_id  counter_name    site_id  site_name  coordinates  \
# 48321           1            10  100007049          5           10
# 48324           1            10  100007049          5           10
# 48327           1            10  100007049          5           10
# 48330           1            10  100007049          5           10
# 48333           1            10  100007049          5           10
#
#        counter_technical_id   latitude  longitude  year  month  day  weekday  \
# 48321                     0  48.846028   2.375429  2020      9    1        1
# 48324                     0  48.846028   2.375429  2020      9    1        1
# 48327                     0  48.846028   2.375429  2020      9    1        1
# 48330                     0  48.846028   2.375429  2020      9    1        1
# 48333                     0  48.846028   2.375429  2020      9    1        1
#
#        hour  is_weekend  installation_year
# 48321     2           0               2013
# 48324     3           0               2013
# 48327     4           0               2013
# 48330    15           0               2013
# 48333    18           0               2013

# %%
X_train.dtypes
# Out:
# counter_id                int64
# counter_name              int64
# site_id                   int64
# site_name                 int64
# coordinates               int64
# counter_technical_id      int64
# latitude                float64
# longitude               float64
# year                      int32
# month                     int32
# day                       int32
# weekday                   int32
# hour                      int32
# is_weekend                int64
# installation_year         int32
# dtype: object

# %%
# Initialize TPOT for regression
tpot = TPOTRegressor(
    generations=5,
    population_size=20,
    verbosity=2,
    scoring='neg_root_mean_squared_error',  # RMSE as the evaluation metric
    random_state=42,
    n_jobs=-1
)

# %%
# Fit Pipeline to Training Data
tpot.fit(X_train, y_train)

# Make Predictions on Test Data
y_predictions = tpot.predict(X_test)
# Out:
# Optimization Progress:   0%|          | 0/120 [00:00<?, ?pipeline/s]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
#
#
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/base.py:1164: SyntaxWarning: invalid escape sequence '\w'
#   (m.start(), m.end()) for m in re.finditer(", [\w]+__", dirty_string)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/louisleibovici/Documents/VS_Code/Bike_counters DSB Project/bike_counters/Dev_by_sam_&_louis/Feature engineering + Model option 2 simple AUTOML.ipynb Cell 14 line 2
#       <a href='vscode-notebook-cell:/Users/louisleibovici/Documents/VS_Code/Bike_counters%20DSB%20Project/bike_counters/Dev_by_sam_%26_louis/Feature%20engineering%20%2B%20Model%20option%202%20simple%20AUTOML.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> # Fit Pipeline to Training Data
# ----> <a href='vscode-notebook-cell:/Users/louisleibovici/Documents/VS_Code/Bike_counters%20DSB%20Project/bike_counters/Dev_by_sam_%26_louis/Feature%20engineering%20%2B%20Model%20option%202%20simple%20AUTOML.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> tpot.fit(X_train, y_train)
#       <a href='vscode-notebook-cell:/Users/louisleibovici/Documents/VS_Code/Bike_counters%20DSB%20Project/bike_counters/Dev_by_sam_%26_louis/Feature%20engineering%20%2B%20Model%20option%202%20simple%20AUTOML.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> # Make Predictions on Test Data
#       <a href='vscode-notebook-cell:/Users/louisleibovici/Documents/VS_Code/Bike_counters%20DSB%20Project/bike_counters/Dev_by_sam_%26_louis/Feature%20engineering%20%2B%20Model%20option%202%20simple%20AUTOML.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> y_predictions = tpot.predict(X_test)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/base.py:864, in TPOTBase.fit(self, features, target, sample_weight, groups)
#     861     except (KeyboardInterrupt, SystemExit, Exception) as e:
#     862         # raise the exception if it's our last attempt
#     863         if attempt == (attempts - 1):
# --> 864             raise e
#     865 return self
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/base.py:855, in TPOTBase.fit(self, features, target, sample_weight, groups)
#     852 if not isinstance(self._pbar, type(None)):
#     853     self._pbar.close()
# --> 855 self._update_top_pipeline()
#     856 self._summary_of_best_pipeline(features, target)
#     857 # Delete the temporary cache before exiting
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tpot/base.py:963, in TPOTBase._update_top_pipeline(self)
#     959             self._last_optimized_pareto_front_n_gens = 0
#     960 else:
#     961     # If user passes CTRL+C in initial generation, self._pareto_front (halloffame) shoule be not updated yet.
#     962     # need raise RuntimeError because no pipeline has been optimized
# --> 963     raise RuntimeError(
#     964         "A pipeline has not yet been optimized. Please call fit() first."
#     965     )
#
# RuntimeError: A pipeline has not yet been optimized. Please call fit() first.

# %%
print(y_predictions)
# Out:
# [0.36719066 1.5280361  1.9501511  ... 5.169382   4.6053843  3.5775466 ]

# %%
pd.DataFrame(y_predictions, columns=["log_bike_count"]).reset_index().rename(
    columns={"index": "Id"}
).to_csv("/Users/louisleibovici/Documents/VS_Code/Bike_counters DSB Project/bike_counters/predictions_option_2_vsimple_AUTOML.csv", index=False)
